# %% [markdown]
# ## Llama Index and Llama 2 tutorial on Lonestar 6
#
# Llama2 is the Meta open source Large Language Model. LlamaIndex is a python library that connects data to the LLMs such as Llama2. This allows the user to quickly use their unstructured data as a basis for any chats or outputs.

# %%
import os
import logging
import sys
from IPython.display import Markdown, display

from llama_index.llms import HuggingFaceLLM
from llama_index.prompts import PromptTemplate, PromptType
from pathlib import Path
from llama_index import download_loader, KnowledgeGraphIndex,  Document, SummaryIndex
logging.basicConfig(stream=sys.stdout, level=logging.INFO)
logging.getLogger().addHandler(logging.StreamHandler(stream=sys.stdout))

import re

# %%
import torch

# %% [markdown]
# ## Set your working directory
# Change your working directory to your Scratch location. This will improve performance, and ensure you have access to the model you rsynced earlier

# %%
scratch = ! echo $SCRATCH
os.chdir(scratch[0])
! pwd
# Out:
# /scratch/06659/wmobley

# %% [markdown]
# ## Access the model
# Next we'll access the models. You have 4 models to access the 7 and 13billion parameters chat and normal model. The folder will also have access to the 70b parameter models; however, we have not tested their performance on the LS6 dev machines.

# %%
# Model names (make sure you have access on HF)
LLAMA2_7B = f"{scratch[0]}/HF/noRef/Llama7b"
LLAMA2_7B_CHAT = f"{scratch[0]}/HF/noRef/Llama7bchat"
LLAMA2_13B = f"{scratch[0]}/HF/noRef/Llama-2-13b-chat-hf"
LLAMA2_13B_CHAT = f"{scratch[0]}/HF/noRef/Llama-2-13b-chat-hf"

# %% [markdown]
# ## Select Model
# For this script we will chose the Llama 2 13B parameter chat model.

# %%
selected_model  =LLAMA2_7B_CHAT

# %% [markdown]
# ## Sytem Prompt
# We are going to have llama2 create triplets used in a knowledge graph based on a pdf.
#
# We set up the system prompt below.

# %%
SYSTEM_PROMPT="""You are social scientist researcher. You have been tasked with identifying the topics of research papers. 

Classify the topics of the documents using only the following topics:
            
## Topics
Federal, State, Regional, Local, Operators-in-training, System Operators, Community Members, Not Stage Specific, Source Water, Potable Water Treatment, Potable Water Distribution, Wastewater Collection, Wastewater Treatment, Water Storage, End-Users Storage System, Administrative Processes, Compliance, Strategic Planning, Funding, Worker Safety, Testing, Laboratory, Field, At-home, Effluent at the conclusion of the treatment process, Biological, Chemical, Physical properties, Water received by the end-user, Biological, Chemical, Physical properties, Treatment Process, Equipment Installation, Equipment Operations, Equipment Maintenance, System Components, System Monitoring, Climate and Environment, Cybersecurity, System Breakdown, Hazardous Materials, Background, Application Process, Benefits of Certification, Accessibility of Material, In-Person Training, Library, Online, Cost Considerations, Continuing Education Requirements, Experience Requirements, Previous Education Considerations, Study Tactics, Consequences of Poor Management, Collaboration, Water Governance , Federal policies, regulations , State policies, regulations , Tribal governance , Community Outreach, Water System Stakeholders, Environmental Attorneys, End-Users, Relevance , To environment, To operator, Positive implications, Negative implications, To end user, COVID-19
            
Here are some rules you always follow:
- Do not include numbers before the topics. 
- Generate only the requested output, don't include any other language before or after the requested output.
- Never say thank you, that you are happy to help, that you are an AI agent, etc. Just answer directly.
- Generate professional language typically used in business documents in North America.
- Never generate offensive or foul language.
"""

query_wrapper_prompt = PromptTemplate(
    "[INST]<<SYS>>\n" + SYSTEM_PROMPT + "<</SYS>>\n\n{query_str}[/INST] "
)

# %% [markdown]
# ## Load the Model
# Next we'll load the model. If it can't find the model it will download it.

# %%
llm = HuggingFaceLLM(
    context_window=4096,
    max_new_tokens=2048,
    generate_kwargs={"temperature": 0.0, "do_sample": False},
    query_wrapper_prompt=query_wrapper_prompt,
    tokenizer_name=selected_model,
    model_name=selected_model,
    device_map="auto",
    # change these settings below depending on your GPU
    model_kwargs={"torch_dtype": torch.float16, "load_in_8bit": True, "cache_dir":f"{scratch[0]}/HF/noRef"},
)
print(selected_model)
# Out:
# INFO:torch.distributed.nn.jit.instantiator:Created a temporary directory at /tmp/tmpwkdh0eb6
# Created a temporary directory at /tmp/tmpwkdh0eb6
# INFO:torch.distributed.nn.jit.instantiator:Writing /tmp/tmpwkdh0eb6/_remote_module_non_scriptable.py
# Writing /tmp/tmpwkdh0eb6/_remote_module_non_scriptable.py
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# /scratch/06659/wmobley/HF/noRef/Llama7bchat

# %% [markdown]
# ## Load the PDF documents

# %%
pandas = download_loader("PandasCSVReader")

loader = pandas()

# %%
from llama_index import VectorStoreIndex, ServiceContext, set_global_service_context


# Better Explain Each of these steps. 
topics = {}

# %%
import pandas as pd
documents = pd.read_csv(f'{scratch[0]}/HF/Survey/all_public_interviews.csv')

# %%
documents
# Out:
#       Unnamed: 0             Set     Interview  Page  Block         Speaker  \
# 0              0  21-22 Combined  INTERVIEW 1      1      2  Interviewee 1
# 1              2  21-22 Combined  INTERVIEW 1      1      2  Interviewer 1
# 2              1  21-22 Combined  INTERVIEW 1      1      2  Interviewee 1
# 3              3  21-22 Combined  INTERVIEW 1      1      2  Interviewer 1
# 4              4  21-22 Combined  INTERVIEW 1      2      1  Interviewee 1
# ...          ...             ...           ...   ...    ...             ...
# 8968        4791        April 22  Interview 9     63      1     Interviewee
# 8969        4792        April 22  Interview 9     63      1     Interviewee
# 8970        4794        April 22  Interview 9     63      1     Interviewer
# 8971        4793        April 22  Interview 9     63      1     Interviewee
# 8972        4795        April 22  Interview 9     63      1     Interviewer
#
#                                                    Text Time_Mark
# 0     A sewer project called the [REDACTED], I forge...     00:00
# 1     So like with the new subdivisions coming online?      02:56
# 2     That's what I'm worried about. Yeah, so we're ...     02:59
# 3     I think the scope of what we're trying to look...     04:13
# 4     One challenge on the hauled side of it for us....     04:47
# ...                                                 ...       ...
# 8968  are they in fact, well calling through for som...       134
# 8969                                  off kinda thing.        135
# 8970                                       Yeah. Okay.        136
# 8971  So, moving forward the next few months, that i...       137
# 8972  Yeah. Well, thank you very much. It was great ...       138
#
# [8973 rows x 8 columns]

# %%
for g in documents.groupby(["Interview",'Set']):
    doc_chunks= []
    for text in g[1].Text.tolist():
        doc = Document(text=text)
        doc_chunks.append(doc)
    service_context = ServiceContext.from_defaults(
        llm=llm, embed_model="local:BAAI/bge-small-en"
    )
    set_global_service_context(service_context)

    index = VectorStoreIndex.from_documents(doc_chunks)
    query_engine = index.as_query_engine()
    response = query_engine.query("Provide a list of Topics")

    response_dict = {"".join(g[0]): re.sub('\d', "" , response.response.split(":")[1].replace('\n',"")).replace('()',"").split(".")}
    topics.update(response_dict)
    print(g[0])
# Out:
# Downloading model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# [nltk_data] Downloading package punkt to /tmp/llama_index...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# /work/06659/wmobley/minconda3/lib/python3.11/site-packages/transformers/generation/configuration_utils.py:362: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /work/06659/wmobley/minconda3/lib/python3.11/site-packages/transformers/generation/configuration_utils.py:367: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# ('INTERVIEW 1 ', '21-22 Combined')
# ('INTERVIEW 10 ', '21-22 Combined')
# ('INTERVIEW 11 ', '21-22 Combined')
# ('INTERVIEW 12 ', '21-22 Combined')
# ('INTERVIEW 13 ', '21-22 Combined')
# ('INTERVIEW 14 ', '21-22 Combined')
# ('INTERVIEW 15 ', '21-22 Combined')
# ('INTERVIEW 16 ', '21-22 Combined')
# ('INTERVIEW 17 ', '21-22 Combined')
# ('INTERVIEW 2 ', '21-22 Combined')
# ('INTERVIEW 3 ', '21-22 Combined')
# ('INTERVIEW 4 ', '21-22 Combined')
# ('INTERVIEW 5 ', '21-22 Combined')
# ('INTERVIEW 6 ', '21-22 Combined')
# ('INTERVIEW 7 ', '21-22 Combined')
# ('INTERVIEW 8 ', '21-22 Combined')
# ('INTERVIEW 9 ', '21-22 Combined')
# ('Interview 1 ', 'April 22')
# ('Interview 10 ', 'April 22')
# ('Interview 11 ', 'April 22')
# ('Interview 12 ', 'April 22')
# ('Interview 13 ', 'April 22')
# ('Interview 14 ', 'April 22')
# ('Interview 15 ', 'April 22')
# ('Interview 16 ', 'April 22')
# ('Interview 17 ', 'April 22')
# ('Interview 18 ', 'April 22')
# ('Interview 19 ', 'April 22')
# ('Interview 2 ', 'April 22')
# ('Interview 20 ', 'April 22')
# ('Interview 21 ', 'April 22')
# ('Interview 22 ', 'April 22')
# ('Interview 23 ', 'April 22')
# ('Interview 24 ', 'April 22')
# ('Interview 25', 'April 22')
# ('Interview 26', 'April 22')
# ('Interview 27 ', 'April 22')
# ('Interview 28 ', 'April 22')
# ('Interview 29 ', 'April 22')
# ('Interview 3 ', 'April 22')
# ('Interview 30 ', 'April 22')
# ('Interview 31 ', 'April 22')
# ('Interview 32 ', 'April 22')
# ('Interview 33 ', 'April 22')
# ('Interview 34 ', 'April 22')
# ('Interview 35 ', 'April 22')
# ('Interview 36 ', 'April 22')
# ('Interview 37 ', 'April 22')
# ('Interview 38 ', 'April 22')
# ('Interview 39 ', 'April 22')
# ('Interview 4 ', 'April 22')
# ('Interview 40 ', 'April 22')
# ('Interview 41 ', 'April 22')
# ('Interview 5 ', 'April 22')
# ('Interview 6 ', 'April 22')
# ('Interview 7 ', 'April 22')
# ('Interview 8 ', 'April 22')
# ('Interview 9 ', 'April 22')

# %%
print(response.response)
import json 
with open("CodedSurveyTopics.json", "w") as outfile: 
    json.dump(topics, outfile)
# Out:
# Based on the provided context information, the following are the topics that can be identified in the research papers:
# 1. Federal policies
# 2. State policies
# 3. Tribal governance
# 4. Community outreach
# 5. Water system stakeholders
# 6. Environmental attorneys
# 7. End-users
# 8. Positive implications
# 9. Negative implications
# 10. Operators-in-training
# 111. System operators
# 12. Regional
# 13. Local
# 14. Compliance
# 15. Strategic planning
# 16. Funding
# 17. Worker safety
# 18. Testing
# 19. Laboratory
# 20. Field
# 21. At-home
# 22. Effluent at the conclusion of the treatment process
# 23. Biological properties
# 24. Chemical properties
# 25. Physical properties
# 26. Water received by the end-user
# 27. Treatment process
# 28. Equipment installation
# 29. Equipment operations
# 30. Equipment maintenance
# 31. System components
# 32. System monitoring
# 33. Climate and environment
# 34. Cybersecurity
# 35. System breakdown
# 36. Hazardous materials
# 37. Background
# 38. Application process
# 39. Benefits of certification
# 40. Accessibility of materials
# 41. In-person training
# 42. Library
# 43. Online
# 44. Cost considerations
# 45. Continuing education requirements
# 46. Experience requirements
# 47. Previous education considerations
# 48. Study tactics
# 49. Consequences of poor management
# 50. Collaboration
#
# These are the topics that can be identified based on the provided context information.

# %%
topics
# Out:
# {'INTERVIEW 1 21-22 Combined': ['',
#   ' Federal policies and regulations',
#   ' State policies and regulations',
#   ' Tribal governance and water management',
#   ' Community outreach and engagement',
#   ' Water system stakeholders and their roles',
#   ' Environmental attorneys and their involvement in water management',
#   ' Water governance and its impact on water management',
#   ' Operators-in-training and their role in water management',
#   ' System operators and their responsibilities',
#   ' Local and regional water management practices',
#   ' Potable water treatment and distribution',
#   ' Wastewater collection and treatment',
#   ' Water storage and distribution',
#   ' End-users and their storage systems',
#   ' Administrative processes and their impact on water management',
#   ' Compliance with regulations and standards',
#   ' Strategic planning and its role in water management',
#   ' Funding and financing for water management projects',
#   ' Worker safety and its importance in water management',
#   ' Testing and laboratory analysis in water management',
#   ' Field work and data collection in water management',
#   ' At-home water treatment and distribution',
#   ' Effluent and its impact on the environment',
#   ' Biological, chemical, and physical properties of water',
#   ' Water received by the end-user and its impact on water management',
#   ' Treatment processes and their effectiveness in water management',
#   ' Equipment installation, operations, and maintenance in water management',
#   ' System components and their role in water management',
#   ' System monitoring and its importance in water management',
#   ' Climate and environmental factors and their impact on water managementThese are the topics that can be identified in the research papers based on the provided context and rules',
#   ''],
#  'INTERVIEW 10 21-22 Combined': ['',
#   ' Federal',
#   ' State',
#   ' Regional',
#   ' Local',
#   ' Operators-in-training',
#   ' System Operators',
#   ' Community Members',
#   ' Not Stage Specific',
#   ' Source Water',
#   ' Potable Water Treatment',
#   ' Potable Water Distribution',
#   ' Wastewater Collection',
#   ' Wastewater Treatment',
#   ' Water Storage',
#   ' End-Users Storage System',
#   ' Administrative Processes',
#   ' Compliance',
#   ' Strategic Planning',
#   ' Funding',
#   ' Worker Safety',
#   ' Testing',
#   ' Laboratory',
#   ' Field',
#   ' At-home',
#   ' Effluent at the conclusion of the treatment process',
#   ' Biological',
#   ' Chemical',
#   ' Physical properties',
#   ' Water received by the end-user',
#   ' Biological, Chemical, Physical properties',
#   ' Treatment Process',
#   ' Equipment Installation',
#   ' Equipment Operations',
#   ' Equipment Maintenance',
#   ' System Components',
#   ' System Monitoring',
#   ' Climate and Environment',
#   ' Cybersecurity',
#   ' System Breakdown',
#   ' Hazardous Materials',
#   ' Background',
#   ' Application Process',
#   ' Benefits of Certification',
#   ' Accessibility of Material',
#   ' In-Person Training',
#   ' Library',
#   ' Online',
#   ' Cost Considerations',
#   ' Continuing Education Requirements',
#   ' Experience Requirements',
#   ' Previous Education Considerations',
#   ' Study Tactics',
#   ' Consequences of Poor Management',
#   ' Collaboration',
#   ' Water Governance',
#   ' Federal policies, regulations',
#   ' State policies, regulations',
#   ' Tribal governance',
#   ' Community Outreach',
#   ' Water System Stakeholders',
#   ' Environmental Attorneys',
#   ' End-Users',
#   ' Relevance',
#   ' To environment',
#   ' To operator',
#   ' Positive implications',
#   ' Negative implications',
#   ' To end user',
#   ' COVID-Note'],
#  'INTERVIEW 11 21-22 Combined': ['',
#   ' Water infrastructure',
#   ' Community dysfunction',
#   ' School functioning',
#   ' Council functioning',
#   ' Prioritization of water',
#   ' Limited knowledge',
#   ' Cultural aspects',
#   ' Lack of interest in water',
#   ' Limited prioritization of water',
#   ' Challenges in [REDACTED]Note'],
#  'INTERVIEW 12 21-22 Combined': ['',
#   ' Federal',
#   ' State',
#   ' Regional',
#   ' Local',
#   ' Operators-in-training',
#   ' System Operators',
#   ' Community Members',
#   ' Not Stage Specific',
#   ' Source Water',
#   ' Potable Water Treatment',
#   ' Potable Water Distribution',
#   ' Wastewater Collection',
#   ' Wastewater Treatment',
#   ' Water Storage',
#   ' End-Users Storage System',
#   ' Administrative Processes',
#   ' Compliance',
#   ' Strategic Planning',
#   ' Funding',
#   ' Worker Safety',
#   ' Testing',
#   ' Laboratory',
#   ' Field',
#   ' At-home',
#   ' Effluent at the conclusion of the treatment process',
#   ' Biological',
#   ' Chemical',
#   ' Physical properties',
#   ' Water received by the end-user',
#   ' System Components',
#   ' System Monitoring',
#   ' Climate and Environment',
#   ' Cybersecurity',
#   ' System Breakdown',
#   ' Hazardous Materials',
#   ' Background',
#   ' Application Process',
#   ' Benefits of Certification',
#   ' Accessibility of Material',
#   ' In-Person Training',
#   ' Library',
#   ' Online',
#   ' Cost Considerations',
#   ' Continuing Education Requirements',
#   ' Experience Requirements',
#   ' Previous Education Considerations',
#   ' Study Tactics',
#   ' Consequences of Poor Management',
#   ' Collaboration',
#   ' Water Governance',
#   ' Federal policies, regulations',
#   ' State policies, regulations',
#   ' Tribal governance',
#   ' Community Outreach',
#   ' Water System Stakeholders',
#   ' Environmental Attorneys',
#   ' End-Users',
#   ' Relevance',
#   ' To environment',
#   ' To operator',
#   ' Positive implications',
#   ' Negative implications',
#   ' To end user',
#   ' COVID-I hope this helps! Let me know if you have any further questions',
#   ''],
#  'INTERVIEW 13 21-22 Combined': ['',
#   ' Water quality',
#   ' Water quantity',
#   ' Infrastructure',
#   ' Safety',
#   ' Regulations',
#   ' Governance',
#   ' Environmental impact',
#   ' Operations and maintenance',
#   ' Funding and financing',
#   ' Technological advancements',
#   ' Community involvement',
#   ' Sustainability',
#   ' Resilience',
#   ' Climate change',
#   ' Public healthThese topics are relevant to the discussion of water infrastructure challenges and can be used as a starting point for further research or analysis',
#   ''],
#  'INTERVIEW 14 21-22 Combined': ['',
#   ' Federal policies',
#   ' State policies',
#   ' Tribal governance',
#   ' Community outreach',
#   ' Water system stakeholders',
#   ' Environmental attorneys',
#   ' End-users',
#   ' COVID-',
#   ' Positive implications',
#   ' Negative implications',
#   ' Operators-in-training',
#   ' System operators',
#   ' Local',
#   ' Regional',
#   ' Administrative processes',
#   ' Compliance',
#   ' Strategic planning',
#   ' Funding',
#   ' Worker safety',
#   ' Testing',
#   ' Laboratory',
#   ' Field',
#   ' At-home',
#   ' Effluent at the conclusion of the treatment process',
#   ' Biological properties',
#   ' Chemical properties',
#   ' Physical properties',
#   ' Water received by the end-user',
#   ' Treatment process',
#   ' Equipment installation',
#   ' Equipment operations',
#   ' Equipment maintenance',
#   ' System components',
#   ' System monitoring',
#   ' Climate and environment',
#   ' Cybersecurity',
#   ' System breakdown',
#   ' Hazardous materials',
#   ' Background',
#   ' Application process',
#   ' Benefits of certification',
#   ' Accessibility of materials',
#   ' In-person training',
#   ' Library',
#   ' Online',
#   ' Cost considerations',
#   ' Continuing education requirements',
#   ' Experience requirements',
#   ' Previous education considerations',
#   ' Study tacticsPlease note that some of these topics may overlap or be related to each other, and some may be mentioned multiple times in the text',
#   ''],
#  'INTERVIEW 15 21-22 Combined': ['',
#   ' Federal policies and regulations',
#   ' State policies and regulations',
#   ' Tribal governance',
#   ' Community outreach and engagement',
#   ' Water system stakeholders',
#   ' Environmental attorneys',
#   ' End-users',
#   ' Positive implications and negative implications of water management',
#   ' Water storage and distribution',
#   ' Wastewater collection and treatment',
#   ' Water treatment processes',
#   ' System components and monitoring',
#   ' Climate and environmental factors',
#   ' Cybersecurity and system breakdown',
#   ' Hazardous materials and their management',
#   ' Background and application process of water management certification',
#   ' Benefits of certification and accessibility of materials',
#   ' In-person training and online learning',
#   ' Cost considerations and continuing education requirements',
#   ' Experience requirements and previous education considerations',
#   ' Study tactics and strategies for water management certification',
#   ' Consequences of poor management and collaboration in water management',
#   ' Water governance and federal policies',
#   ' State policies and regulations',
#   ' Tribal governance and community engagement'],
#  'INTERVIEW 16 21-22 Combined': ['',
#   ' Federal',
#   ' State',
#   ' Regional',
#   ' Local',
#   ' Operators-in-training',
#   ' System Operators',
#   ' Community Members',
#   ' Not Stage Specific',
#   ' Source Water',
#   ' Potable Water Treatment',
#   ' Potable Water Distribution',
#   ' Wastewater Collection',
#   ' Wastewater Treatment',
#   ' Water Storage',
#   ' End-Users Storage System',
#   ' Administrative Processes',
#   ' Compliance',
#   ' Strategic Planning',
#   ' Funding',
#   ' Worker Safety',
#   ' Testing',
#   ' Laboratory',
#   ' Field',
#   ' At-home',
#   ' Effluent at the conclusion of the treatment process',
#   ' Biological',
#   ' Chemical',
#   ' Physical properties',
#   ' Water received by the end-user',
#   ' System Components',
#   ' System Monitoring',
#   ' Climate and Environment',
#   ' Cybersecurity',
#   ' System Breakdown',
#   ' Hazardous Materials',
#   ' Background',
#   ' Application Process',
#   ' Benefits of Certification',
#   ' Accessibility of Material',
#   ' In-Person Training',
#   ' Library',
#   ' Online',
#   ' Cost Considerations',
#   ' Continuing Education Requirements',
#   ' Experience Requirements',
#   ' Previous Education Considerations',
#   ' Study Tactics',
#   ' Consequences of Poor Management',
#   ' Collaboration',
#   ' Water Governance',
#   ' Federal policies, regulations',
#   ' State policies, regulations',
#   ' Tribal governance',
#   ' Community Outreach',
#   ' Water System Stakeholders',
#   ' Environmental Attorneys',
#   ' End-Users',
#   ' Relevance',
#   ' To environment',
#   ' To operator',
#   ' Positive implications',
#   ' Negative implications',
#   ' To end user',
#   ' COVID-I hope this helps! Let me know if you have any further questions',
#   ''],
#  'INTERVIEW 17 21-22 Combined': ['',
#   ' Federal policies',
#   ' State policies',
#   ' Regional issues',
#   ' Local issues',
#   ' Operators-in-training',
#   ' System operators',
#   ' Community members',
#   ' Not stage specific',
#   ' Source water',
#   ' Potable water treatment',
#   ' Potable water distribution',
#   ' Wastewater collection',
#   ' Wastewater treatment',
#   ' Water storage',
#   ' End-users storage system',
#   ' Administrative processes',
#   ' Compliance',
#   ' Strategic planning',
#   ' Funding',
#   ' Worker safety',
#   ' Testing',
#   ' Laboratory',
#   ' Field',
#   ' At-home',
#   ' Effluent at the conclusion of the treatment process',
#   ' Biological properties',
#   ' Chemical properties',
#   ' Physical properties',
#   ' Water received by the end-user',
#   ' System components',
#   ' System monitoring',
#   ' Climate and environment',
#   ' Cybersecurity',
#   ' System breakdown',
#   ' Hazardous materials',
#   ' Background',
#   ' Application process',
#   ' Benefits of certification',
#   ' Accessibility of materials',
#   ' In-person training',
#   ' Library',
#   ' Online',
#   ' Cost considerations',
#   ' Continuing education requirements',
#   ' Experience requirements',
#   ' Previous education considerations',
#   ' Study tactics',
#   ' Consequences of poor management',
#   ' Collaboration',
#   ' Water governanceThese are the topics that can be identified in the research papers based on the provided context and rules',
#   ''],
#  'INTERVIEW 2 21-22 Combined': ['',
#   ' Federal policies and regulations',
#   ' State policies and regulations',
#   ' Tribal governance',
#   ' Community outreach and engagement',
#   ' Water system stakeholders',
#   ' Environmental attorneys',
#   ' End-users',
#   ' Positive implications of water management',
#   ' Negative implications of water management',
#   ' Water governance',
#   ' System breakdown and failures',
#   ' Climate and environmental factors',
#   ' Cybersecurity and data protection',
#   ' Cost considerations and budgeting',
#   ' Continuing education and training requirements',
#   ' Experience requirements and qualifications',
#   ' Study tactics and strategies for water management',
#   ' Consequences of poor water management',
#   ' Collaboration and partnerships in water management',
#   ' Water storage and distribution',
#   ' End-user storage systems',
#   ' Administrative processes and procedures',
#   ' Compliance and regulatory requirements',
#   ' Strategic planning and long-term planning',
#   ' Funding and financial management',
#   ' Worker safety and health',
#   ' Testing and laboratory analysis',
#   ' Fieldwork and data collection',
#   ' At-home water treatment and management',
#   ' Effluent and wastewater treatment',
#   ' Biological, chemical, and physical properties of water',
#   ' Water received by the end-user',
#   ' Treatment processes and technologies',
#   ' Equipment installation and operations',
#   ' Equipment maintenance and repair',
#   ' System components and their functions',
#   ' System monitoring and control',
#   ' Climate and environmental factors affecting water management',
#   ' Federal, state, and local regulations and policies',
#   ' Water governance and management frameworksI hope this helps! Let me know if you have any further questions',
#   ''],
#  'INTERVIEW 3 21-22 Combined': ['',
#   ' Federal policies and regulations',
#   ' State policies and regulations',
#   ' Tribal governance',
#   ' Community outreach and engagement',
#   ' Water system stakeholders',
#   ' Environmental attorneys',
#   ' End-users',
#   ' COVID- pandemic and its impact on water management',
#   ' Positive implications of water management practices',
#   ' Negative implications of water management practices',
#   ' Funding sources and considerations (including loans, grants, and cost considerations)',
#   ' Compliance with regulations and standards',
#   ' Strategic planning and decision-making',
#   ' Worker safety and training',
#   ' Testing and laboratory analysis',
#   ' Fieldwork and data collection',
#   ' At-home water treatment and distribution',
#   ' End-user storage systems and management',
#   ' Administrative processes and procedures',
#   ' Water storage and distribution systems',
#   'I hope this helps! Let me know if you have any further questions',
#   ''],
#  'INTERVIEW 4 21-22 Combined': ['',
#   ' Federal',
#   ' State',
#   ' Regional',
#   ' Local',
#   ' Operators-in-training',
#   ' System Operators',
#   ' Community Members',
#   ' Not Stage Specific',
#   ' Source Water',
#   ' Potable Water Treatment',
#   ' Potable Water Distribution',
#   ' Wastewater Collection',
#   ' Wastewater Treatment',
#   ' Water Storage',
#   ' End-Users Storage System',
#   ' Administrative Processes',
#   ' Compliance',
#   ' Strategic Planning',
#   ' Funding',
#   ' Worker Safety',
#   ' Testing',
#   ' Laboratory',
#   ' Field',
#   ' At-home',
#   ' Effluent at the conclusion of the treatment process',
#   ' Biological',
#   ' Chemical',
#   ' Physical properties',
#   ' Water received by the end-user',
#   ' Biological',
#   ' Chemical',
#   ' Physical properties',
#   ' Treatment Process',
#   ' Equipment Installation',
#   ' Equipment Operations',
#   ' Equipment Maintenance',
#   ' System Components',
#   ' System Monitoring',
#   ' Climate and Environment',
#   ' Cybersecurity',
#   ' System Breakdown',
#   ' Hazardous Materials',
#   ' Background',
#   ' Application Process',
#   ' Benefits of Certification',
#   ' Accessibility of Material',
#   ' In-Person Training',
#   ' Library',
#   ' Online',
#   ' Cost Considerations',
#   ' Continuing Education Requirements',
#   ' Experience Requirements',
#   ' Previous Education Considerations',
#   ' Study Tactics',
#   ' Consequences of Poor Management',
#   ' Collaboration',
#   ' Water Governance',
#   ' Federal policies, regulations',
#   ' State policies, regulations',
#   ' Tribal governance',
#   ' Community Outreach',
#   ' Water System Stakeholders',
#   ' Environmental Attorneys',
#   ' End-Users',
#   ' Relevance',
#   ' To environment',
#   ' To operator',
#   ' Positive implications',
#   ' Negative implications',
#   ' To end user',
#   ' COVID-Note'],
#  'INTERVIEW 5 21-22 Combined': ['',
#   ' Federal policies',
#   ' State policies',
#   ' Tribal governance',
#   ' Community outreach',
#   ' Water system stakeholders',
#   ' Environmental attorneys',
#   ' End-users',
#   ' Positive implications',
#   ' Negative implications',
#   ' Operators-in-training',
#   ' System operators',
#   ' Local',
#   ' Regional',
#   ' Compliance',
#   ' Strategic planning',
#   ' Funding',
#   ' Worker safety',
#   ' Testing',
#   ' Laboratory',
#   ' Field',
#   ' At-home',
#   ' Effluent at the conclusion of the treatment process',
#   ' Biological properties',
#   ' Chemical properties',
#   ' Physical properties',
#   ' Water received by the end-user',
#   ' Treatment process',
#   ' Equipment installation',
#   ' Equipment operations',
#   ' Equipment maintenance',
#   ' System components',
#   ' System monitoring',
#   ' Climate and environment',
#   ' Cybersecurity',
#   ' System breakdown',
#   ' Hazardous materials',
#   ' Background',
#   ' Application process',
#   ' Benefits of certification',
#   ' Accessibility of materials',
#   ' In-person training',
#   ' Library',
#   ' Online',
#   ' Cost considerations',
#   ' Continuing education requirements',
#   ' Experience requirements',
#   ' Previous education considerations',
#   ' Study tactics',
#   ' Consequences of poor management',
#   ' CollaborationPlease note that some of these topics may overlap or be mentioned multiple times in the given text, but I have categorized them based on their primary focus or context',
#   ''],
#  'INTERVIEW 6 21-22 Combined': ['',
#   ' Federal policies',
#   ' State policies',
#   ' Tribal governance',
#   ' Community outreach',
#   ' Water system stakeholders',
#   ' Environmental attorneys',
#   ' End-users',
#   ' Positive implications',
#   ' Negative implications',
#   ' Infrastructure',
#   ' Public health',
#   ' Operators-in-training',
#   ' System operators',
#   ' Compliance',
#   ' Strategic planning',
#   ' Funding',
#   ' Worker safety',
#   ' Testing',
#   ' Laboratory',
#   ' Field',
#   ' At-home',
#   ' Effluent at the conclusion of the treatment process',
#   ' Biological properties',
#   ' Chemical properties',
#   ' Physical properties',
#   ' Water received by the end-user',
#   ' Treatment process',
#   ' Equipment installation',
#   ' Equipment operations',
#   ' Equipment maintenance',
#   ' System components',
#   ' System monitoring',
#   ' Climate and environment',
#   ' Cybersecurity',
#   ' System breakdown',
#   ' Hazardous materials',
#   ' Background',
#   ' Application process',
#   ' Benefits of certification',
#   ' Accessibility of materials',
#   ' In-person training',
#   ' Library',
#   ' Online',
#   ' Cost considerations',
#   ' Continuing education requirements',
#   ' Experience requirements',
#   ' Previous education considerations',
#   ' Study tactics',
#   ' Consequences of poor management',
#   ' CollaborationThese are the topics that can be identified from the given text based on the provided rules and context information',
#   ''],
#  'INTERVIEW 7 21-22 Combined': ['',
#   ' Federal policies and regulations',
#   ' State policies and regulations',
#   ' Tribal governance',
#   ' Community outreach and engagement',
#   ' Water system stakeholders',
#   ' Environmental attorneys',
#   ' End-users',
#   ' Positive implications of water management',
#   ' Negative implications of water management',
#   ' Water storage and distribution',
#   ' Wastewater collection and treatment',
#   ' Potable water treatment and distribution',
#   ' Water breakdown and system failures',
#   ' Hazardous materials and their impact on water systems',
#   ' Background and history of water management',
#   ' Application process for water certification',
#   ' Benefits of water certification for end-users',
#   ' Accessibility of water management materials',
#   ' In-person training and library resources',
#   ' Online training and continuing education requirements',
#   ' Cost considerations for water management',
#   ' Continuing education requirements for water management professionals',
#   ' Experience requirements for water management professionals',
#   ' Previous education considerations for water management professionals',
#   ' Study tactics and strategies for water management professionals',
#   ' Consequences of poor water management practices',
#   ' Collaboration and teamwork in water management',
#   ' Water governance and policy-making',
#   ' Federal policies and regulations affecting water management',
#   ' State policies and regulations affecting water managementI hope this helps! Let me know if you have any further questions',
#   ''],
#  'INTERVIEW 8 21-22 Combined': ['',
#   ' Federal',
#   ' State',
#   ' Regional',
#   ' Local',
#   ' Operators-in-training',
#   ' System Operators',
#   ' Community Members',
#   ' Not Stage Specific',
#   ' Source Water',
#   ' Potable Water Treatment',
#   ' Potable Water Distribution',
#   ' Wastewater Collection',
#   ' Wastewater Treatment',
#   ' Water Storage',
#   ' End-Users Storage System',
#   ' Administrative Processes',
#   ' Compliance',
#   ' Strategic Planning',
#   ' Funding',
#   ' Worker Safety',
#   ' Testing',
#   ' Laboratory',
#   ' Field',
#   ' At-home',
#   ' Effluent at the conclusion of the treatment process',
#   ' Biological',
#   ' Chemical',
#   ' Physical properties',
#   ' Water received by the end-user',
#   ' Biological, Chemical, Physical properties',
#   ' Treatment Process',
#   ' Equipment Installation',
#   ' Equipment Operations',
#   ' Equipment Maintenance',
#   ' System Components',
#   ' System Monitoring',
#   ' Climate and Environment',
#   ' Cybersecurity',
#   ' System Breakdown',
#   ' Hazardous Materials',
#   ' Background',
#   ' Application Process',
#   ' Benefits of Certification',
#   ' Accessibility of Material',
#   ' In-Person Training',
#   ' Library',
#   ' Online',
#   ' Cost Considerations',
#   ' Continuing Education Requirements',
#   ' Experience Requirements',
#   ' Previous Education Considerations',
#   ' Study Tactics',
#   ' Consequences of Poor Management',
#   ' Collaboration',
#   ' Water Governance',
#   ' Federal policies, regulations',
#   ' State policies, regulations',
#   ' Tribal governance',
#   ' Community Outreach',
#   ' Water System Stakeholders',
#   ' Environmental Attorneys',
#   ' End-Users',
#   ' Relevance',
#   ' To environment',
#   ' To operator',
#   ' Positive implications',
#   ' Negative implications',
#   ' To end user',
#   ' COVID-Note'],
#  'INTERVIEW 9 21-22 Combined': ['',
#   ' Federal',
#   ' State',
#   ' Regional',
#   ' Local',
#   ' Operators-in-training',
#   ' System Operators',
#   ' Community Members',
#   ' Not Stage Specific',
#   ' Source Water',
#   ' Potable Water Treatment',
#   ' Potable Water Distribution',
#   ' Wastewater Collection',
#   ' Wastewater Treatment',
#   ' Water Storage',
#   ' End-Users Storage System',
#   ' Administrative Processes',
#   ' Compliance',
#   ' Strategic Planning',
#   ' Funding',
#   ' Worker Safety',
#   ' Testing',
#   ' Laboratory',
#   ' Field',
#   ' At-home',
#   ' Effluent at the conclusion of the treatment process',
#   ' Biological',
#   ' Chemical',
#   ' Physical properties',
#   ' Water received by the end-user',
#   ' Treatment Process',
#   ' Equipment Installation',
#   ' Equipment Operations',
#   ' Equipment Maintenance',
#   ' System Components',
#   ' System Monitoring',
#   ' Climate and Environment',
#   ' Cybersecurity',
#   ' System Breakdown',
#   ' Hazardous Materials',
#   ' Background',
#   ' Application Process',
#   ' Benefits of Certification',
#   ' Accessibility of Material',
#   ' In-Person Training',
#   ' Library',
#   ' Online',
#   ' Cost Considerations',
#   ' Continuing Education Requirements',
#   ' Experience Requirements',
#   ' Previous Education Considerations',
#   ' Study Tactics',
#   ' Consequences of Poor Management',
#   ' Collaboration',
#   ' Water Governance',
#   ' Federal policies, regulations',
#   ' State policies, regulations',
#   ' Tribal governance',
#   ' Community Outreach',
#   ' Water System Stakeholders',
#   ' Environmental Attorneys',
#   ' End-Users',
#   ' To environment',
#   ' To operator',
#   ' Positive implications',
#   ' Negative implications',
#   ' To end-user',
#   ' COVID-Note'],
#  'Interview 1 April 22': ['',
#   ' Federal policies and regulations',
#   ' State policies and regulations',
#   ' Tribal governance',
#   ' Community outreach and engagement',
#   ' Water system stakeholders',
#   ' Environmental attorneys',
#   ' End-users',
#   ' Positive implications of water management',
#   ' Negative implications of water management',
#   ' Water storage and distribution',
#   ' Wastewater collection and treatment',
#   ' Laboratory testing and analysis',
#   ' Field testing and analysis',
#   ' At-home water treatment systems',
#   ' Equipment installation, operations, and maintenance',
#   ' System components and monitoring',
#   ' Climate and environmental factors affecting water management',
#   ' Cybersecurity in water management',
#   ' System breakdown and recovery',
#   ' Hazardous materials handling and disposalThese topics are relevant to the research papers based on the provided context information and do not include any specific numbers or other language not relevant to the topic',
#   ''],
#  'Interview 10 April 22': ['',
#   ' Federal policies',
#   ' State policies',
#   ' Regional',
#   ' Local',
#   ' Operators-in-training',
#   ' System operators',
#   ' Community members',
#   ' Not stage specific',
#   ' Source water',
#   ' Potable water treatment',
#   ' Potable water distribution',
#   ' Wastewater collection',
#   ' Wastewater treatment',
#   ' Water storage',
#   ' End-users storage system',
#   ' Administrative processes',
#   ' Compliance',
#   ' Strategic planning',
#   ' Funding',
#   ' Worker safety',
#   ' Testing',
#   ' Laboratory',
#   ' Field',
#   ' At-home',
#   ' Effluent at the conclusion of the treatment process',
#   ' Biological',
#   ' Chemical',
#   ' Physical properties',
#   ' Water received by the end-user',
#   ' System components',
#   ' System monitoring',
#   ' Climate and environment',
#   ' Cybersecurity',
#   ' System breakdown',
#   ' Hazardous materials',
#   ' Background',
#   ' Application process',
#   ' Benefits of certification',
#   ' Accessibility of materials',
#   ' In-person training',
#   ' Library',
#   ' Online',
#   ' Cost considerations',
#   ' Continuing education requirements',
#   ' Experience requirements',
#   ' Previous education considerations',
#   ' Study tactics',
#   ' Consequences of poor management',
#   ' Collaboration',
#   ' Water governanceThese are the topics that can be identified in the research papers based on the provided context and rules',
#   ''],
#  'Interview 11 April 22': ['',
#   ' Federal policies',
#   ' State policies',
#   ' Regional issues',
#   ' Local issues',
#   ' Operators-in-training',
#   ' System operators',
#   ' Community members',
#   ' Not stage specific',
#   ' Source water',
#   ' Potable water treatment',
#   ' Potable water distribution',
#   ' Wastewater collection',
#   ' Wastewater treatment',
#   ' Water storage',
#   ' End-users storage system',
#   ' Administrative processes',
#   ' Compliance',
#   ' Strategic planning',
#   ' Funding',
#   ' Worker safety',
#   ' Testing',
#   ' Laboratory',
#   ' Field',
#   ' At-home',
#   ' Effluent at the conclusion of the treatment process',
#   ' Biological properties',
#   ' Chemical properties',
#   ' Physical properties',
#   ' Water received by the end-user',
#   ' System components',
#   ' System monitoring',
#   ' Climate and environment',
#   ' Cybersecurity',
#   ' System breakdown',
#   ' Hazardous materials',
#   ' Background',
#   ' Application process',
#   ' Benefits of certification',
#   ' Accessibility of materials',
#   ' In-person training',
#   ' Library',
#   ' Online',
#   ' Cost considerations',
#   ' Continuing education requirements',
#   ' Experience requirements',
#   ' Previous education considerations',
#   ' Study tactics',
#   ' Consequences of poor management',
#   ' Collaboration',
#   ' Water governanceThese are the topics that can be identified in the research papers based on the provided context and rules',
#   ''],
#  'Interview 12 April 22': ['',
#   ' Federal policies',
#   ' State policies',
#   ' Regional issues',
#   ' Local issues',
#   ' Operators-in-training',
#   ' System operators',
#   ' Community members',
#   ' Not stage specific',
#   ' Source water',
#   ' Potable water treatment',
#   ' Potable water distribution',
#   ' Wastewater collection',
#   ' Wastewater treatment',
#   ' Water storage',
#   ' End-users storage system',
#   ' Administrative processes',
#   ' Compliance',
#   ' Strategic planning',
#   ' Funding',
#   ' Worker safety',
#   ' Testing',
#   ' Laboratory',
#   ' Field',
#   ' At-home',
#   ' Effluent at the conclusion of the treatment process',
#   ' Biological properties',
#   ' Chemical properties',
#   ' Physical properties',
#   ' Water received by the end-user',
#   ' System components',
#   ' System monitoring',
#   ' Climate and environment',
#   ' Cybersecurity',
#   ' System breakdown',
#   ' Hazardous materials',
#   ' Background',
#   ' Application process',
#   ' Benefits of certification',
#   ' Accessibility of materials',
#   ' In-person training',
#   ' Library',
#   ' Online',
#   ' Cost considerations',
#   ' Continuing education requirements',
#   ' Experience requirements',
#   ' Previous education considerations',
#   ' Study tactics',
#   ' Consequences of poor management',
#   ' Collaboration',
#   ' Water governanceThese are the topics that can be identified in the research papers based on the provided context and rules',
#   ''],
#  'Interview 13 April 22': ['',
#   ' Federal policies',
#   ' State policies',
#   ' Tribal governance',
#   ' Community outreach',
#   ' Water system stakeholders',
#   ' Environmental attorneys',
#   ' End-users',
#   ' Positive implications',
#   ' Negative implications',
#   ' Operators-in-training',
#   ' System operators',
#   ' Laboratory',
#   ' Field',
#   ' At-home',
#   ' Effluent at the conclusion of the treatment process',
#   ' Biological properties',
#   ' Chemical properties',
#   ' Physical properties',
#   ' Water received by the end-user',
#   ' Treatment process',
#   ' Equipment installation',
#   ' Equipment operations',
#   ' Equipment maintenance',
#   ' System components',
#   ' System monitoring',
#   ' Climate and environment',
#   ' Cybersecurity',
#   ' System breakdown',
#   ' Hazardous materials',
#   ' Background',
#   ' Application process',
#   ' Benefits of certification',
#   ' Accessibility of materials',
#   ' In-person training',
#   ' Library',
#   ' Online',
#   ' Cost considerations',
#   ' Continuing education requirements',
#   ' Experience requirements',
#   ' Previous education considerations',
#   ' Study tactics',
#   ' Consequences of poor management',
#   ' Collaboration',
#   ' Water governance',
#   ' Federal policies',
#   ' State policies',
#   ' Regional',
#   ' Local',
#   ' Administrative processes',
#   ' ComplianceThese are the topics that can be identified in the given documents based on the provided context and rules',
#   ''],
#  'Interview 14 April 22': ['',
#   ' Federal',
#   ' State',
#   ' Regional',
#   ' Local',
#   ' Operators-in-training',
#   ' System Operators',
#   ' Community Members',
#   ' Not Stage Specific',
#   ' Source Water',
#   ' Potable Water Treatment',
#   ' Potable Water Distribution',
#   ' Wastewater Collection',
#   ' Wastewater Treatment',
#   ' Water Storage',
#   ' End-Users Storage System',
#   ' Administrative Processes',
#   ' Compliance',
#   ' Strategic Planning',
#   ' Funding',
#   ' Worker Safety',
#   ' Testing',
#   ' Laboratory',
#   ' Field',
#   ' At-home',
#   ' Effluent at the conclusion of the treatment process',
#   ' Biological',
#   ' Chemical',
#   ' Physical properties',
#   ' Water received by the end-user',
#   ' Treatment Process',
#   ' Equipment Installation',
#   ' Equipment Operations',
#   ' Equipment Maintenance',
#   ' System Components',
#   ' System Monitoring',
#   ' Climate and Environment',
#   ' Cybersecurity',
#   ' System Breakdown',
#   ' Hazardous Materials',
#   ' Background',
#   ' Application Process',
#   ' Benefits of Certification',
#   ' Accessibility of Material',
#   ' In-Person Training',
#   ' Library',
#   ' Online',
#   ' Cost Considerations',
#   ' Continuing Education Requirements',
#   ' Experience Requirements',
#   ' Previous Education Considerations',
#   ' Study Tactics',
#   ' Consequences of Poor Management',
#   ' Collaboration',
#   ' Water Governance',
#   ' Federal policies, regulations',
#   ' State policies, regulations',
#   ' Tribal governance',
#   ' Community Outreach',
#   ' Water System Stakeholders',
#   ' Environmental Attorneys',
#   ' End-Users',
#   ' Relevance',
#   ' To environment',
#   ' To operator',
#   ' Positive implications',
#   ' Negative implications',
#   ' To end user',
#   ' COVID-I hope this helps! Let me know if you have any further questions',
#   ''],
#  'Interview 15 April 22': ['',
#   ' Federal policies',
#   ' State policies',
#   ' Tribal governance',
#   ' Community outreach',
#   ' Water system stakeholders',
#   ' Environmental attorneys',
#   ' End-users',
#   ' COVID-',
#   ' Positive implications',
#   ' Negative implications',
#   ' Operators-in-training',
#   ' System operators',
#   ' Local',
#   ' Regional',
#   ' System components',
#   ' System monitoring',
#   ' Climate and environment',
#   ' Cybersecurity',
#   ' System breakdown',
#   ' Hazardous materialsThese are the topics that can be identified in the research papers based on the provided context and rules',
#   ''],
#  'Interview 16 April 22': ['',
#   ' Federal policies',
#   ' State policies',
#   ' Tribal governance',
#   ' Community outreach',
#   ' Water system stakeholders',
#   ' Environmental attorneys',
#   ' End-users',
#   ' Positive implications',
#   ' Negative implications',
#   ' To end-user',
#   ' COVID-These topics are relevant to the research papers as they are related to the systems of water in households, including federal and state policies, tribal governance, community outreach, water system stakeholders, environmental attorneys, end-users, and the impact of water systems on the environment and end-users',
#   ''],
#  'Interview 17 April 22': ['',
#   ' Federal policies',
#   ' State policies',
#   ' Regional',
#   ' Local',
#   ' Operators-in-training',
#   ' System operators',
#   ' Community members',
#   ' Not stage specific',
#   ' Source water',
#   ' Potable water treatment',
#   ' Potable water distribution',
#   ' Wastewater collection',
#   ' Wastewater treatment',
#   ' Water storage',
#   ' End-users storage system',
#   ' Administrative processes',
#   ' Compliance',
#   ' Strategic planning',
#   ' Funding',
#   ' Worker safety',
#   ' Testing',
#   ' Laboratory',
#   ' Field',
#   ' At-home',
#   ' Effluent at the conclusion of the treatment process',
#   ' Biological properties',
#   ' Chemical properties',
#   ' Physical properties',
#   ' Water received by the end-user',
#   ' Treatment process',
#   ' Equipment installation',
#   ' Equipment operations',
#   ' Equipment maintenance',
#   ' System components',
#   ' System monitoring',
#   ' Climate and environment',
#   ' Cybersecurity',
#   ' System breakdown',
#   ' Hazardous materials',
#   ' Background',
#   ' Application process',
#   ' Benefits of certification',
#   ' Accessibility of materials',
#   ' In-person training',
#   ' Library',
#   ' Online',
#   ' Cost considerations',
#   ' Continuing education requirements',
#   ' Experience requirements',
#   ' Previous education considerations',
#   ' Study tactics',
#   ' Consequences of poor management',
#   ' Collaboration',
#   ' Water governance',
#   ' Federal policies',
#   ' State policies',
#   ' Tribal governance',
#   ' Community outreach',
#   ' Water system stakeholders',
#   ' Environmental attorneys',
#   ' End-users',
#   ' Relevance',
#   ' To environment',
#   ' To operator',
#   ' Positive implications',
#   ' Negative implications',
#   ' To end-user',
#   ' COVID-These are the topics that can be identified in the research papers based on the provided context and rules',
#   ''],
#  'Interview 18 April 22': ['',
#   ' Federal policies',
#   ' State policies',
#   ' Tribal governance',
#   ' Community outreach',
#   ' Water system stakeholders',
#   ' Environmental attorneys',
#   ' End-users',
#   ' Positive implications',
#   ' Negative implications',
#   ' To end-user',
#   ' COVID-',
#   ' Operators-in-training',
#   ' System operators',
#   ' Regional',
#   ' Local',
#   ' Compliance',
#   ' Strategic planning',
#   ' Funding',
#   ' Worker safety',
#   ' Testing',
#   ' Laboratory',
#   ' Field',
#   ' At-home',
#   ' Effluent at the conclusion of the treatment process',
#   ' Biological properties',
#   ' Chemical properties',
#   ' Physical properties',
#   ' Water received by the end-user',
#   ' Treatment process',
#   ' Equipment installation',
#   ' Equipment operations',
#   ' Equipment maintenance',
#   ' System components',
#   ' System monitoring',
#   ' Climate and environment',
#   ' Cybersecurity',
#   ' System breakdown',
#   ' Hazardous materials',
#   ' Background',
#   ' Application process',
#   ' Benefits of certification',
#   ' Accessibility of materials',
#   ' In-person training',
#   ' Library',
#   ' Online',
#   ' Cost considerations',
#   ' Continuing education requirements',
#   ' Experience requirements',
#   ' Previous education considerations',
#   ' Study tactics',
#   ' Consequences of poor management',
#   ' Collaboration',
#   ' Water governanceThese are the topics that can be identified based on the provided context and rules',
#   ''],
#  'Interview 19 April 22': ['', ' Federal'],
#  'Interview 2 April 22': ['',
#   ' Federal policies and regulations',
#   ' State policies and regulations',
#   ' Tribal governance',
#   ' Community outreach',
#   ' Water system stakeholders',
#   ' Environmental attorneys',
#   ' End-users',
#   ' Positive implications',
#   ' Negative implications',
#   ' Operators-in-training',
#   ' System operators',
#   ' Laboratory',
#   ' Field',
#   ' At-home',
#   ' Effluent at the conclusion of the treatment process',
#   ' Biological properties',
#   ' Chemical properties',
#   ' Physical properties',
#   ' Water received by the end-user',
#   ' Treatment process',
#   ' Equipment installation',
#   ' Equipment operations',
#   ' Equipment maintenance',
#   ' System components',
#   ' System monitoring',
#   ' Climate and environment',
#   ' Cybersecurity',
#   ' System breakdown',
#   ' Hazardous materials',
#   ' Background',
#   ' Application process',
#   ' Benefits of certification',
#   ' Accessibility of materials',
#   ' In-person training',
#   ' Library',
#   ' Online',
#   ' Cost considerations',
#   ' Continuing education requirements',
#   ' Experience requirements',
#   ' Previous education considerations',
#   ' Study tactics',
#   ' Consequences of poor management',
#   ' Collaboration',
#   ' Water governance',
#   ' Federal policies and regulations',
#   ' State policies and regulations',
#   ' Tribal governance',
#   ' Community outreach',
#   ' Water system stakeholders',
#   ' Environmental attorneysThese are the topics that can be identified based on the provided context information',
#   ''],
#  'Interview 20 April 22': ['',
#   ' Federal policies',
#   ' State policies',
#   ' Regional',
#   ' Local',
#   ' Operators-in-training',
#   ' System operators',
#   ' Community members',
#   ' Not stage specific',
#   ' Source water',
#   ' Potable water treatment',
#   ' Potable water distribution',
#   ' Wastewater collection',
#   ' Wastewater treatment',
#   ' Water storage',
#   ' End-users storage system',
#   ' Administrative processes',
#   ' Compliance',
#   ' Strategic planning',
#   ' Funding',
#   ' Worker safety',
#   ' Testing',
#   ' Laboratory',
#   ' Field',
#   ' At-home',
#   ' Effluent at the conclusion of the treatment process',
#   ' Biological properties',
#   ' Chemical properties',
#   ' Physical properties',
#   ' Water received by the end-user',
#   ' Treatment process',
#   ' Equipment installation',
#   ' Equipment operations',
#   ' Equipment maintenance',
#   ' System components',
#   ' System monitoring',
#   ' Climate and environment',
#   ' Cybersecurity',
#   ' System breakdown',
#   ' Hazardous materials',
#   ' Background',
#   ' Application process',
#   ' Benefits of certification',
#   ' Accessibility of materials',
#   ' In-person training',
#   ' Library',
#   ' Online',
#   ' Cost considerations',
#   ' Continuing education requirements',
#   ' Experience requirements',
#   ' Previous education considerations',
#   ' Study tactics',
#   ' Consequences of poor management',
#   ' Collaboration',
#   ' Water governance',
#   ' Federal policies',
#   ' State policies',
#   ' Tribal governance',
#   ' Community outreach',
#   ' Water system stakeholders',
#   ' Environmental attorneys',
#   ' End-users',
#   ' Relevance',
#   ' To environment',
#   ' To operator',
#   ' Positive implications',
#   ' Negative implications',
#   ' To end-user',
#   ' COVID-Please note that some of these topics may overlap or be related to each other, but they can be categorized into these main topics based on the information provided',
#   ''],
#  'Interview 21 April 22': ['',
#   ' Federal policies',
#   ' State policies',
#   ' Tribal governance',
#   ' Community outreach',
#   ' Water system stakeholders',
#   ' Environmental attorneys',
#   ' End-users',
#   ' Positive implications',
#   ' Negative implications',
#   ' To end-user',
#   ' COVID-',
#   ' Operators-in-training',
#   ' System operators',
#   ' Regional',
#   ' Local',
#   ' Administrative processes',
#   ' Compliance',
#   ' Strategic planning',
#   ' Funding',
#   ' Worker safety',
#   ' Testing',
#   ' Laboratory',
#   ' Field',
#   ' At-home',
#   ' Effluent at the conclusion of the treatment process',
#   ' Biological properties',
#   ' Chemical properties',
#   ' Physical properties',
#   ' Water received by the end-user',
#   ' Treatment process',
#   ' Equipment installation',
#   ' Equipment operations',
#   ' Equipment maintenance',
#   ' System components',
#   ' System monitoring',
#   ' Climate and environment',
#   ' Cybersecurity',
#   ' System breakdown',
#   ' Hazardous materials',
#   ' Background',
#   ' Application process',
#   ' Benefits of certification',
#   ' Accessibility of materials',
#   ' In-person training',
#   ' Library',
#   ' Online',
#   ' Cost considerations',
#   ' Continuing education requirements',
#   ' Experience requirements',
#   ' Previous education considerations',
#   ' Study tactics',
#   ' Consequences of poor management',
#   ' Collaboration',
#   ' Water governance',
#   ' Federal policies',
#   ' State policies',
#   ' Tribal governance',
#   ' Community outreach',
#   ' Water system stakeholdersThese are the topics that can be identified in the research papers based on the provided context and rules',
#   ''],
#  'Interview 22 April 22': ['', ' Federal'],
#  'Interview 23 April 22': ['',
#   ' Federal policies',
#   ' State policies',
#   ' Tribal governance',
#   ' Community outreach',
#   ' Water system stakeholders',
#   ' Environmental attorneys',
#   ' End-users',
#   ' COVID-',
#   ' Positive implications',
#   ' Negative implications',
#   ' Operators-in-training',
#   ' System operators',
#   ' Local',
#   ' Regional',
#   ' System components',
#   ' System monitoring',
#   ' Climate and environment',
#   ' Cybersecurity',
#   ' System breakdown',
#   ' Hazardous materialsThese topics are relevant to the text based on the language used and the context provided',
#   ''],
#  'Interview 24 April 22': ['',
#   ' Federal policies and regulations',
#   ' State policies and regulations',
#   ' Tribal governance',
#   ' Community outreach and engagement',
#   ' Water system stakeholders',
#   ' Environmental attorneys',
#   ' End-users',
#   ' Positive implications of water management',
#   ' Negative implications of water management',
#   ' Water storage and distribution',
#   ' Potable water treatment',
#   ' Wastewater collection and treatment',
#   ' Water governance',
#   ' System breakdown and failures',
#   ' Hazardous materials handling and disposal',
#   ' Background and history of water management',
#   ' Application process for water management certification',
#   ' Benefits of water management certification',
#   ' Accessibility of training materials',
#   ' In-person training and library resources',
#   ' Online training and continuing education requirements',
#   ' Experience requirements for water management certification',
#   ' Previous education considerations for water management certification',
#   ' Study tactics and exam preparation for water management certification',
#   ' Consequences of poor water management',
#   ' Collaboration and teamwork in water management',
#   ' Climate and environmental factors affecting water management',
#   ' Cybersecurity and system protection',
#   ' System monitoring and control',
#   ' Cost considerations for water management systems'],
#  'Interview 25April 22': ['',
#   ' Federal policies and regulations',
#   ' State policies and regulations',
#   ' Tribal governance and water management',
#   ' Community outreach and engagement',
#   ' Water system stakeholders and their roles',
#   ' Environmental attorneys and their involvement in water management',
#   ' Water storage and distribution',
#   ' Potable water treatment and its methods',
#   ' Wastewater collection and treatment',
#   ' System components and their maintenance',
#   ' System monitoring and control',
#   ' Climate and environmental factors affecting water management',
#   ' Cybersecurity and its importance in water management',
#   ' System breakdowns and their impact on water delivery',
#   ' Hazardous materials handling and disposal',
#   ' Background and history of water management in the region',
#   ' Application process for water certification',
#   ' Benefits of water certification for end-users',
#   ' Accessibility of water management materials for in-person and online training',
#   ' Cost considerations and budgeting for water management systems',
#   ' Continuing education requirements for water management professionals',
#   ' Experience requirements for water management professionals',
#   ' Previous education considerations for water management professionals',
#   ' Study tactics and strategies for water management professionals',
#   ' Consequences of poor water management and its impact on the environment and community',
#   ' Collaboration and partnerships in water management',
#   ' Water governance and its role in water management',
#   ' Federal, state, and local regulations and their impact on water management',
#   ' Environmental impact of water management practices',
#   ' Positive and negative implications of water management practices on the environment and community',
#   ''],
#  'Interview 26April 22': ['',
#   ' Federal',
#   ' State',
#   ' Regional',
#   ' Local',
#   ' Operators-in-training',
#   ' System Operators',
#   ' Community Members',
#   ' Not Stage Specific',
#   ' Source Water',
#   ' Potable Water Treatment',
#   ' Potable Water Distribution',
#   ' Wastewater Collection',
#   ' Wastewater Treatment',
#   ' Water Storage',
#   ' End-Users Storage System',
#   ' Administrative Processes',
#   ' Compliance',
#   ' Strategic Planning',
#   ' Funding',
#   ' Worker Safety',
#   ' Testing',
#   ' Laboratory',
#   ' Field',
#   ' At-home',
#   ' Effluent at the conclusion of the treatment process',
#   ' Biological',
#   ' Chemical',
#   ' Physical properties',
#   ' Water received by the end-user',
#   ' System Components',
#   ' System Monitoring',
#   ' Climate and Environment',
#   ' Cybersecurity',
#   ' System Breakdown',
#   ' Hazardous Materials',
#   ' Background',
#   ' Application Process',
#   ' Benefits of Certification',
#   ' Accessibility of Material',
#   ' In-Person Training',
#   ' Library',
#   ' Online',
#   ' Cost Considerations',
#   ' Continuing Education Requirements',
#   ' Experience Requirements',
#   ' Previous Education Considerations',
#   ' Study Tactics',
#   ' Consequences of Poor Management',
#   ' Collaboration',
#   ' Water Governance',
#   ' Federal policies, regulations',
#   ' State policies, regulations',
#   ' Tribal governance',
#   ' Community Outreach',
#   ' Water System Stakeholders',
#   ' Environmental Attorneys',
#   ' End-Users',
#   ' Relevance',
#   ' To environment',
#   ' To operator',
#   ' Positive implications',
#   ' Negative implications',
#   ' To end user',
#   ' COVID-These are the topics that can be identified from the given documents based on the provided context and rules',
#   ''],
#  'Interview 27 April 22': ['',
#   ' Federal policies and regulations',
#   ' State policies and regulations',
#   ' Tribal governance',
#   ' Community outreach and engagement',
#   ' Water system stakeholders',
#   ' Environmental attorneys',
#   ' End-users',
#   ' Positive implications of water management',
#   ' Negative implications of water management',
#   ' Water storage',
#   ' End-users storage system',
#   ' Administrative processes',
#   ' Compliance',
#   ' Strategic planning',
#   ' Funding',
#   ' Worker safety',
#   ' Testing and laboratory analysis',
#   ' Field work and data collection',
#   ' At-home water treatment',
#   ' Effluent at the conclusion of the treatment process',
# ...
#   ' Worker safety and health in water management',
#   ' Testing and laboratory analysis in water management',
#   ' Fieldwork and data collection in water management',
#   ' At-home water treatment and managementThese topics are relevant to the field of water management and are likely to be covered in research papers related to this field',
#   ''],
#  'Interview 35 April 22': ['',
#   ' Federal policies',
#   ' State policies',
#   ' Tribal governance',
#   ' Community outreach',
#   ' Water system stakeholders',
#   ' Environmental attorneys',
#   ' End-users',
#   ' COVID-',
#   ' Positive implications',
#   ' Negative implications',
#   ' To end-user',
#   ' Operators-in-training',
#   ' System operators',
#   ' Laboratory',
#   ' Field',
#   ' At-home',
#   ' Effluent at the conclusion of the treatment process',
#   ' Biological properties',
#   ' Chemical properties',
#   ' Physical properties',
#   ' Water received by the end-user',
#   ' Treatment process',
#   ' Equipment installation',
#   ' Equipment operations',
#   ' Equipment maintenance',
#   ' System components',
#   ' System monitoring',
#   ' Climate and environment',
#   ' Cybersecurity',
#   ' System breakdown',
#   ' Hazardous materials',
#   ' Background',
#   ' Application process',
#   ' Benefits of certification',
#   ' Accessibility of materials',
#   ' In-person training',
#   ' Library',
#   ' Online',
#   ' Cost considerations',
#   ' Continuing education requirements',
#   ' Experience requirements',
#   ' Previous education considerations',
#   ' Study tactics',
#   ' Consequences of poor management',
#   ' Collaboration',
#   ' Water governance',
#   ' Federal policies',
#   ' State policies',
#   ' Regional',
#   ' LocalPlease note that some of these topics may overlap or be mentioned multiple times in the given documents, but I have attempted to categorize them based on their primary focus or relevance',
#   ''],
#  'Interview 36 April 22': ['',
#   ' Water Governance',
#   ' Federal policies',
#   ' State policies',
#   ' Tribal governance',
#   ' Community Outreach',
#   ' Water System Stakeholders',
#   ' Environmental Attorneys',
#   ' End-Users',
#   ' Positive implications',
#   ' Negative implications',
#   ' To end-user',
#   ' COVID-Please note that these topics are based on the information provided in the query and may not be exhaustive or accurate for all cases',
#   ''],
#  'Interview 37 April 22': ['',
#   ' Federal policies',
#   ' State policies',
#   ' Tribal governance',
#   ' Community outreach',
#   ' Water system stakeholders',
#   ' Environmental attorneys',
#   ' End-users',
#   ' Positive implications',
#   ' Negative implications',
#   ' To end-user',
#   ' COVID-',
#   ' Operators-in-training',
#   ' System operators',
#   ' Regional',
#   ' Local',
#   ' Compliance',
#   ' Strategic planning',
#   ' Funding',
#   ' Worker safety',
#   ' Testing',
#   ' Laboratory',
#   ' Field',
#   ' At-home',
#   ' Effluent at the conclusion of the treatment process',
#   ' Biological properties',
#   ' Chemical properties',
#   ' Physical properties',
#   ' Water received by the end-user',
#   ' Treatment process',
#   ' Equipment installation',
#   ' Equipment operations',
#   ' Equipment maintenance',
#   ' System components',
#   ' System monitoring',
#   ' Climate and environment',
#   ' Cybersecurity',
#   ' System breakdown',
#   ' Hazardous materials',
#   ' Background',
#   ' Application process',
#   ' Benefits of certification',
#   ' Accessibility of materials',
#   ' In-person training',
#   ' Library',
#   ' Online',
#   ' Cost considerations',
#   ' Continuing education requirements',
#   ' Experience requirements',
#   ' Previous education considerations',
#   ' Study tactics',
#   ' Consequences of poor management',
#   ' Collaboration',
#   ' Water governanceThese are the topics that can be identified based on the provided context information',
#   ''],
#  'Interview 38 April 22': ['', ' Federal'],
#  'Interview 39 April 22': ['',
#   ' Federal policies and regulations',
#   ' State policies and regulations',
#   ' Tribal governance',
#   ' Community outreach and engagement',
#   ' Water system stakeholders',
#   ' Environmental attorneys',
#   ' End-users',
#   ' Positive implications of water management',
#   ' Negative implications of water management',
#   ' Water storage and distribution',
#   ' Wastewater collection and treatment',
#   ' Water treatment processes',
#   ' System components and monitoring',
#   ' Climate and environmental factors',
#   ' Cybersecurity in water management',
#   ' System breakdown and recovery',
#   ' Hazardous materials management',
#   ' Background and history of water management',
#   ' Application process and requirements',
#   ' Benefits of certification and training',
#   ' Accessibility of materials and training',
#   ' In-person training and library resources',
#   ' Online training and continuing education requirements',
#   ' Experience requirements and previous education considerations',
#   ' Study tactics and exam preparation',
#   ' Consequences of poor management and governance',
#   ' Collaboration and stakeholder engagement',
#   ' Water governance and policy',
#   ' Federal, state, and local regulations and laws',
#   ' Cost considerations and budgeting for water management'],
#  'Interview 4 April 22': ['',
#   ' Federal policies and regulations',
#   ' State policies and regulations',
#   ' Tribal governance',
#   ' Community outreach',
#   ' Water system stakeholders',
#   ' Environmental attorneys',
#   ' End-users',
#   ' Positive implications',
#   ' Negative implications',
#   ' Operators-in-training',
#   ' System operators',
#   ' Local',
#   ' Regional',
#   ' System components',
#   ' System monitoring',
#   ' Climate and environment',
#   ' Cybersecurity',
#   ' System breakdown',
#   ' Hazardous materials',
#   ' Background',
#   ' Application process',
#   ' Benefits of certification',
#   ' Accessibility of materials',
#   ' In-person training',
#   ' Library',
#   ' Online',
#   ' Cost considerations',
#   ' Continuing education requirements',
#   ' Experience requirements',
#   ' Previous education considerations',
#   ' Study tactics',
#   ' Consequences of poor management',
#   ' Collaboration',
#   ' Water governance',
#   ' Federal policies and regulations',
#   ' State policies and regulations',
#   ' Tribal governance',
#   ' Community outreach',
#   ' Water system stakeholders',
#   ' Environmental attorneys',
#   ' End-users',
#   ' RelevanceThese are the topics that can be identified based on the provided context information',
#   ''],
#  'Interview 40 April 22': ['',
#   ' Federal policies',
#   ' State policies',
#   ' Regional governance',
#   ' Local regulations',
#   ' Operators-in-training',
#   ' System operators',
#   ' Community members',
#   ' Not stage specific',
#   ' Source water',
#   ' Potable water treatment',
#   ' Potable water distribution',
#   ' Wastewater collection',
#   ' Wastewater treatment',
#   ' Water storage',
#   ' End-users storage system',
#   ' Administrative processes',
#   ' Compliance',
#   ' Strategic planning',
#   ' Funding',
#   ' Worker safety',
#   ' Testing',
#   ' Laboratory',
#   ' Field work',
#   ' At-home testing',
#   ' Effluent at the conclusion of the treatment process',
#   ' Biological properties',
#   ' Chemical properties',
#   ' Physical properties',
#   ' Water received by the end-user',
#   ' System components',
#   ' System monitoring',
#   ' Climate and environment',
#   ' Cybersecurity',
#   ' System breakdown',
#   ' Hazardous materials',
#   ' Background',
#   ' Application process',
#   ' Benefits of certification',
#   ' Accessibility of materials',
#   ' In-person training',
#   ' Online training',
#   ' Cost considerations',
#   ' Continuing education requirements',
#   ' Experience requirements',
#   ' Previous education considerations',
#   ' Study tactics',
#   ' Consequences of poor management',
#   ' Collaboration',
#   ' Water governance',
#   ' Federal policies',
#   ' State policies',
#   ' Tribal governance',
#   ' Community outreach',
#   ' Water system stakeholders',
#   ' Environmental attorneys',
#   ' End-users',
#   ' Relevance',
#   ' To environment',
#   ' To operator',
#   ' Positive implications',
#   ' Negative implications',
#   ' To end-user',
#   ' COVID-These are the topics that can be identified based on the provided documents and rules',
#   ''],
#  'Interview 41 April 22': ['',
#   ' Federal policies',
#   ' State policies',
#   ' Regional issues',
#   ' Local issues',
#   ' Operators-in-training',
#   ' System operators',
#   ' Community members',
#   ' Not stage specific',
#   ' Source water',
#   ' Potable water treatment',
#   ' Potable water distribution',
#   ' Wastewater collection',
#   ' Wastewater treatment',
#   ' Water storage',
#   ' End-users storage system',
#   ' Administrative processes',
#   ' Compliance',
#   ' Strategic planning',
#   ' Funding',
#   ' Worker safety',
#   ' Testing',
#   ' Laboratory',
#   ' Field',
#   ' At-home',
#   ' Effluent at the conclusion of the treatment process',
#   ' Biological properties',
#   ' Chemical properties',
#   ' Physical properties',
#   ' Water received by the end-user',
#   ' Treatment process',
#   ' Equipment installation',
#   ' Equipment operations',
#   ' Equipment maintenance',
#   ' System components',
#   ' System monitoring',
#   ' Climate and environment',
#   ' Cybersecurity',
#   ' System breakdown',
#   ' Hazardous materials',
#   ' Background',
#   ' Application process',
#   ' Benefits of certification',
#   ' Accessibility of materials',
#   ' In-person training',
#   ' Library',
#   ' Online',
#   ' Cost considerations',
#   ' Continuing education requirements',
#   ' Experience requirements',
#   ' Previous education considerations',
#   ' Study tactics',
#   ' Consequences of poor management',
#   ' Collaboration',
#   ' Water governance',
#   ' Federal policies',
#   ' State policies',
#   ' Tribal governance',
#   ' Community outreach',
#   ' Water system stakeholders',
#   ' Environmental attorneys',
#   ' End-users',
#   ' Relevance',
#   ' To environment',
#   ' To operator',
#   ' Positive implications',
#   ' Negative implications',
#   ' To end-user',
#   ' COVID-These are the topics that can be identified in the research papers based on the provided context and rules',
#   ''],
#  'Interview 5 April 22': ['',
#   ' Federal policies',
#   ' State policies',
#   ' Regional',
#   ' Local',
#   ' Operators-in-training',
#   ' System operators',
#   ' Community members',
#   ' Not stage specific',
#   ' Source water',
#   ' Potable water treatment',
#   ' Potable water distribution',
#   ' Wastewater collection',
#   ' Wastewater treatment',
#   ' Water storage',
#   ' End-users storage system',
#   ' Administrative processes',
#   ' Compliance',
#   ' Strategic planning',
#   ' Funding',
#   ' Worker safety',
#   ' Testing',
#   ' Laboratory',
#   ' Field',
#   ' At-home',
#   ' Effluent at the conclusion of the treatment process',
#   ' Biological properties',
#   ' Chemical properties',
#   ' Physical properties',
#   ' Water received by the end-user',
#   ' Treatment process',
#   ' Equipment installation',
#   ' Equipment operations',
#   ' Equipment maintenance',
#   ' System components',
#   ' System monitoring',
#   ' Climate and environment',
#   ' Cybersecurity',
#   ' System breakdown',
#   ' Hazardous materials',
#   ' Background',
#   ' Application process',
#   ' Benefits of certification',
#   ' Accessibility of materials',
#   ' In-person training',
#   ' Library',
#   ' Online',
#   ' Cost considerations',
#   ' Continuing education requirements',
#   ' Experience requirements',
#   ' Previous education considerations',
#   ' Study tactics',
#   ' Consequences of poor management',
#   ' Collaboration',
#   ' Water governance',
#   ' Federal policies',
#   ' State policies',
#   ' Tribal governance',
#   ' Community outreach',
#   ' Water system stakeholders',
#   ' Environmental attorneys',
#   ' End-users',
#   ' Relevance',
#   ' To environment',
#   ' To operator',
#   ' Positive implications',
#   ' Negative implications',
#   ' To end-user',
#   ' COVID-These are the topics that can be identified in the research papers based on the provided information',
#   ''],
#  'Interview 6 April 22': ['',
#   ' Federal',
#   ' State',
#   ' Regional',
#   ' Local',
#   ' Operators-in-training',
#   ' System Operators',
#   ' Community Members',
#   ' Not Stage Specific',
#   ' Source Water',
#   ' Potable Water Treatment',
#   ' Potable Water Distribution',
#   ' Wastewater Collection',
#   ' Wastewater Treatment',
#   ' Water Storage',
#   ' End-Users Storage System',
#   ' Administrative Processes',
#   ' Compliance',
#   ' Strategic Planning',
#   ' Funding',
#   ' Worker Safety',
#   ' Testing',
#   ' Laboratory',
#   ' Field',
#   ' At-home',
#   ' Effluent at the conclusion of the treatment process',
#   ' Biological',
#   ' Chemical',
#   ' Physical properties',
#   ' Water received by the end-user',
#   ' Treatment Process',
#   ' Equipment Installation',
#   ' Equipment Operations',
#   ' Equipment Maintenance',
#   ' System Components',
#   ' System Monitoring',
#   ' Climate and Environment',
#   ' Cybersecurity',
#   ' System Breakdown',
#   ' Hazardous Materials',
#   ' Background',
#   ' Application Process',
#   ' Benefits of Certification',
#   ' Accessibility of Material',
#   ' In-Person Training',
#   ' Library',
#   ' Online',
#   ' Cost Considerations',
#   ' Continuing Education Requirements',
#   ' Experience Requirements',
#   ' Previous Education Considerations',
#   ' Study Tactics',
#   ' Consequences of Poor Management',
#   ' Collaboration',
#   ' Water Governance',
#   ' Federal policies, regulations',
#   ' State policies, regulations',
#   ' Tribal governance',
#   ' Community Outreach',
#   ' Water System Stakeholders',
#   ' Environmental Attorneys',
#   ' End-Users',
#   ' RelevanceI hope this helps! Let me know if you have any further questions',
#   ''],
#  'Interview 7 April 22': ['',
#   ' Federal policies',
#   ' State policies',
#   ' Regional',
#   ' Local',
#   ' Operators-in-training',
#   ' System operators',
#   ' Community members',
#   ' Not stage specific',
#   ' Source water',
#   ' Potable water treatment',
#   ' Potable water distribution',
#   ' Wastewater collection',
#   ' Wastewater treatment',
#   ' Water storage',
#   ' End-users storage system',
#   ' Administrative processes',
#   ' Compliance',
#   ' Strategic planning',
#   ' Funding',
#   ' Worker safety',
#   ' Testing',
#   ' Laboratory',
#   ' Field',
#   ' At-home',
#   ' Effluent at the conclusion of the treatment process',
#   ' Biological',
#   ' Chemical',
#   ' Physical properties',
#   ' Water received by the end-user',
#   ' System components',
#   ' System monitoring',
#   ' Climate and environment',
#   ' Cybersecurity',
#   ' System breakdown',
#   ' Hazardous materials',
#   ' Background',
#   ' Application process',
#   ' Benefits of certification',
#   ' Accessibility of materials',
#   ' In-person training',
#   ' Library',
#   ' Online',
#   ' Cost considerations',
#   ' Continuing education requirements',
#   ' Experience requirements',
#   ' Previous education considerations',
#   ' Study tactics',
#   ' Consequences of poor management',
#   ' Collaboration',
#   ' Water governanceThese are the topics that can be identified in the research papers based on the provided context and rules',
#   ''],
#  'Interview 8 April 22': ['', ' Federal'],
#  'Interview 9 April 22': ['',
#   ' Federal policies',
#   ' State policies',
#   ' Tribal governance',
#   ' Community outreach',
#   ' Water system stakeholders',
#   ' Environmental attorneys',
#   ' End-users',
#   ' Positive implications',
#   ' Negative implications',
#   ' Operators-in-training',
#   ' System operators',
#   ' Regional',
#   ' Local',
#   ' Compliance',
#   ' Strategic planning',
#   ' Funding',
#   ' Worker safety',
#   ' Testing',
#   ' Laboratory',
#   ' Field',
#   ' At-home',
#   ' Effluent at the conclusion of the treatment process',
#   ' Biological properties',
#   ' Chemical properties',
#   ' Physical properties',
#   ' Water received by the end-user',
#   ' Treatment process',
#   ' Equipment installation',
#   ' Equipment operations',
#   ' Equipment maintenance',
#   ' System components',
#   ' System monitoring',
#   ' Climate and environment',
#   ' Cybersecurity',
#   ' System breakdown',
#   ' Hazardous materials',
#   ' Background',
#   ' Application process',
#   ' Benefits of certification',
#   ' Accessibility of materials',
#   ' In-person training',
#   ' Library',
#   ' Online',
#   ' Cost considerations',
#   ' Continuing education requirements',
#   ' Experience requirements',
#   ' Previous education considerations',
#   ' Study tactics',
#   ' Consequences of poor management',
#   ' CollaborationThese are the topics that can be identified based on the provided context information',
#   '']}
