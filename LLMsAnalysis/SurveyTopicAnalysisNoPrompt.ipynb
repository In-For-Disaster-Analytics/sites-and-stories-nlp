# %% [markdown]
# ## Llama Index and Llama 2 tutorial on Lonestar 6
#
# Llama2 is the Meta open source Large Language Model. LlamaIndex is a python library that connects data to the LLMs such as Llama2. This allows the user to quickly use their unstructured data as a basis for any chats or outputs.

# %%
import os
import logging
import sys
from IPython.display import Markdown, display

from llama_index.llms import HuggingFaceLLM
from llama_index.prompts import PromptTemplate, PromptType
from pathlib import Path
from llama_index import download_loader, KnowledgeGraphIndex,  Document, SummaryIndex
logging.basicConfig(stream=sys.stdout, level=logging.INFO)
logging.getLogger().addHandler(logging.StreamHandler(stream=sys.stdout))

import re

# %%
import torch

# %% [markdown]
# ## Set your working directory
# Change your working directory to your Scratch location. This will improve performance, and ensure you have access to the model you rsynced earlier

# %%
scratch = ! echo $SCRATCH
os.chdir(scratch[0])
! pwd
# Out:
# /scratch/06659/wmobley

# %% [markdown]
# ## Access the model
# Next we'll access the models. You have 4 models to access the 7 and 13billion parameters chat and normal model. The folder will also have access to the 70b parameter models; however, we have not tested their performance on the LS6 dev machines.

# %%
# Model names (make sure you have access on HF)
LLAMA2_7B = f"{scratch[0]}/HF/noRef/Llama7b"
LLAMA2_7B_CHAT = f"{scratch[0]}/HF/noRef/Llama7bchat"
LLAMA2_13B = "meta-llama/Llama-2-13b-hf"
LLAMA2_13B_CHAT = "meta-llama/Llama-2-13b-chat-hf"

# %% [markdown]
# ## Select Model
# For this script we will chose the Llama 2 13B parameter chat model.

# %%
selected_model  =LLAMA2_7B_CHAT

# %% [markdown]
# ## Sytem Prompt
# We are going to have llama2 create triplets used in a knowledge graph based on a pdf.
#
# We set up the system prompt below.

# %%
SYSTEM_PROMPT="""You are social scientist researcher. You have been tasked with identifying the topics of research papers. 

         
Here are some rules you always follow:
- Do not include numbers before the topics. 
- Generate only the requested output, don't include any other language before or after the requested output.
- Never say thank you, that you are happy to help, that you are an AI agent, etc. Just answer directly.
- Generate professional language typically used in business documents in North America.
- Never generate offensive or foul language.
"""

query_wrapper_prompt = PromptTemplate(
    "[INST]<<SYS>>\n" + SYSTEM_PROMPT + "<</SYS>>\n\n{query_str}[/INST] "
)

# %% [markdown]
# ## Load the Model
# Next we'll load the model. If it can't find the model it will download it.

# %%
llm = HuggingFaceLLM(
    context_window=4096,
    max_new_tokens=2048,
    generate_kwargs={"temperature": 0.0, "do_sample": False},
    query_wrapper_prompt=query_wrapper_prompt,
    tokenizer_name=selected_model,
    model_name=selected_model,
    device_map="auto",
    # change these settings below depending on your GPU
    model_kwargs={"torch_dtype": torch.float16, "load_in_8bit": True, "cache_dir":f"{scratch[0]}/HF/noRef"},
)
print(selected_model)
# Out:
# INFO:torch.distributed.nn.jit.instantiator:Created a temporary directory at /tmp/tmpwsdu6eko
# Created a temporary directory at /tmp/tmpwsdu6eko
# INFO:torch.distributed.nn.jit.instantiator:Writing /tmp/tmpwsdu6eko/_remote_module_non_scriptable.py
# Writing /tmp/tmpwsdu6eko/_remote_module_non_scriptable.py
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# /scratch/06659/wmobley/HF/noRef/Llama7bchat

# %% [markdown]
# ## Load the PDF documents

# %%
pandas = download_loader("PandasCSVReader")

loader = pandas()

# %%
from llama_index import VectorStoreIndex, ServiceContext, set_global_service_context


# Better Explain Each of these steps. 
topics = {}

# %%
import pandas as pd
documents = pd.read_csv(f'{scratch[0]}/HF/Survey/all_public_interviews.csv')

# %%
for g in documents.groupby(["Interview",'Set']):
    doc_chunks= []
    for text in g[1].Text.tolist():
        doc = Document(text=text)
        doc_chunks.append(doc)
    service_context = ServiceContext.from_defaults(
        llm=llm, embed_model="local:BAAI/bge-small-en"
    )
    set_global_service_context(service_context)

    index = VectorStoreIndex.from_documents(doc_chunks)
    query_engine = index.as_query_engine()
    response = query_engine.query("Provide a list of Topics")

    response_dict = {"".join(g[0]): re.sub('\d', "" , response.response.split(":")[1].replace('\n',"")).replace('()',"").split(".")}
    topics.update(response_dict)
    print(g[0])
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/684 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# [nltk_data] Downloading package punkt to /tmp/llama_index...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# /work/06659/wmobley/minconda3/lib/python3.11/site-packages/transformers/generation/configuration_utils.py:362: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /work/06659/wmobley/minconda3/lib/python3.11/site-packages/transformers/generation/configuration_utils.py:367: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# ('INTERVIEW 1 ', '21-22 Combined')
# ('INTERVIEW 10 ', '21-22 Combined')
# ('INTERVIEW 11 ', '21-22 Combined')
# ('INTERVIEW 12 ', '21-22 Combined')
# ('INTERVIEW 13 ', '21-22 Combined')
# ('INTERVIEW 14 ', '21-22 Combined')
# ('INTERVIEW 15 ', '21-22 Combined')
# ('INTERVIEW 16 ', '21-22 Combined')
# ('INTERVIEW 17 ', '21-22 Combined')
# ('INTERVIEW 2 ', '21-22 Combined')
# ('INTERVIEW 3 ', '21-22 Combined')
# ('INTERVIEW 4 ', '21-22 Combined')
# ('INTERVIEW 5 ', '21-22 Combined')
# ('INTERVIEW 6 ', '21-22 Combined')
# ('INTERVIEW 7 ', '21-22 Combined')
# ('INTERVIEW 8 ', '21-22 Combined')
# ('INTERVIEW 9 ', '21-22 Combined')
# ('Interview 1 ', 'April 22')
# ('Interview 10 ', 'April 22')
# ('Interview 11 ', 'April 22')
# ('Interview 12 ', 'April 22')
# ('Interview 13 ', 'April 22')
# ('Interview 14 ', 'April 22')
# ('Interview 15 ', 'April 22')
# ('Interview 16 ', 'April 22')
# ('Interview 17 ', 'April 22')
# ('Interview 18 ', 'April 22')
# ('Interview 19 ', 'April 22')
# ('Interview 2 ', 'April 22')
# ('Interview 20 ', 'April 22')
# ('Interview 21 ', 'April 22')
# ('Interview 22 ', 'April 22')
# ('Interview 23 ', 'April 22')
# ('Interview 24 ', 'April 22')
# ('Interview 25', 'April 22')
# ('Interview 26', 'April 22')
# ('Interview 27 ', 'April 22')
# ('Interview 28 ', 'April 22')
# ('Interview 29 ', 'April 22')
# ('Interview 3 ', 'April 22')
# ('Interview 30 ', 'April 22')
# ('Interview 31 ', 'April 22')
# ('Interview 32 ', 'April 22')
# ('Interview 33 ', 'April 22')
# ('Interview 34 ', 'April 22')
# ('Interview 35 ', 'April 22')
# ('Interview 36 ', 'April 22')
# ('Interview 37 ', 'April 22')
# ('Interview 38 ', 'April 22')
# ('Interview 39 ', 'April 22')
# ('Interview 4 ', 'April 22')
# ('Interview 40 ', 'April 22')
# ('Interview 41 ', 'April 22')
# ('Interview 5 ', 'April 22')
# ('Interview 6 ', 'April 22')
# ('Interview 7 ', 'April 22')
# ('Interview 8 ', 'April 22')
# ('Interview 9 ', 'April 22')

# %%
print(response.response)
import json 
with open("NonCodedSurveyTopics.json", "w") as outfile: 
    json.dump(topics, outfile)
# Out:
# Certainly! Based on the provided context information, here are the potential topics of research papers that could be relevant to the scenario:
# 1. Pipeline infrastructure and management
# 2. Deferred revenue accounting and reporting
# 3. Urban planning and development strategies for water delivery systems
# 4. Sustainable water management practices and technologies
# 5. Water pipeline design and engineering
# 6. Water supply chain management and logistics
# 7. Financial modeling and forecasting for water infrastructure projects
# 8. Public-private partnerships in water infrastructure development
# 9. Water policy and regulation analysis
# 10. Stakeholder engagement and public participation in water infrastructure planning.

# %%
topics
# Out:
# {'INTERVIEW 1 21-22 Combined': ['',
#   ' Public perceptions and attitudes towards water quality and management',
#   ' Communication strategies for engaging the public in water-related decision-making processes',
#   ' Stakeholder analysis and mapping for water-related projects',
#   ' Public participation and involvement in water governance',
#   ' Water literacy and education'],
#  'INTERVIEW 10 21-22 Combined': ['',
#   ' Water access and availability in tribal communities',
#   ' Collaboration between tribes and health corporations in water management',
#   ' Public perceptions and attitudes towards water in tribal areas',
#   ' The role of traditional knowledge in water management in tribal communities',
#   ' The impact of water scarcity on tribal cultures and traditions',
#   ' Collaborative approaches to water management in tribal areas',
#   ' The intersection of water and cultural heritage in tribal communities',
#   ' The role of indigenous knowledge in water conservation and sustainability',
#   ' The impact of climate change on water resources in tribal areas',
#   ' The importance of inclusive decision-making processes in water management in tribal communities',
#   ''],
#  'INTERVIEW 11 21-22 Combined': ['',
#   ' The relationship between community functioning and water infrastructure'],
#  'INTERVIEW 12 21-22 Combined': ['',
#   ' [REDACTED]',
#   ' [REDACTED]',
#   ' [REDACTED]',
#   ' [REDACTED]',
#   ' [REDACTED]',
#   ' [REDACTED]',
#   ' [REDACTED]',
#   ' [REDACTED]',
#   ' [REDACTED]',
#   ' [REDACTED]'],
#  'INTERVIEW 13 21-22 Combined': ['',
#   ' Quality and Quantity of Water Infrastructure'],
#  'INTERVIEW 14 21-22 Combined': ['',
#   ' The impact of language barriers on water treatment plant operations'],
#  'INTERVIEW 15 21-22 Combined': ['',
#   ' The impact of social media on mental health',
#   ' The effects of poverty on child development',
#   ' The role of education in reducing inequality',
#   ' The influence of cultural identity on consumer behavior',
#   ' The relationship between social support and mental health outcomes',
#   ' The impact of technology on face-to-face communication',
#   ' The effects of discrimination on well-being',
#   ' The role of community involvement in promoting social cohesion',
#   ' The influence of political ideology on social policy',
#   ' The impact of climate change on social inequalityI hope these topics provide a good starting point for your research papers! If you have any further questions or need additional information, please let me know',
#   ''],
#  'INTERVIEW 16 21-22 Combined': ['',
#   ' Prioritization in Planning',
#   ' Decision-Making in Planning',
#   ' Time Management in Planning',
#   ' Resource Allocation in Planning',
#   ' Risk Assessment and Management in Planning',
#   ' Stakeholder Engagement in Planning',
#   ' Sustainability in Planning',
#   ' Innovation in Planning',
#   ' Collaboration in Planning',
#   ' Technology in PlanningI hope these topics are helpful! Let me know if you have any further questions',
#   ''],
#  'INTERVIEW 17 21-22 Combined': ['',
#   ' Infrastructure resilience in the face of natural disasters',
#   ' The impact of aging infrastructure on economic growth',
#   ' The role of technology in improving infrastructure sustainability',
#   ' Infrastructure planning and development in emerging economies',
#   ' The social and economic benefits of investing in green infrastructure',
#   ' The challenges and opportunities of implementing smart city technologies',
#   ' The impact of climate change on infrastructure resilience',
#   ' The role of public-private partnerships in infrastructure development',
#   ' Infrastructure financing and funding models',
#   ' The impact of infrastructure on social inequality and access to services',
#   ''],
#  'INTERVIEW 2 21-22 Combined': ['',
#   " The impact of water scarcity on young people's health and well-being in drought-prone regions",
#   '',
#   ' Examining the role of water infrastructure in supporting sustainable agriculture and food systems for young farmers',
#   '',
#   ' Investigating the relationship between water quality and mental health among young people in urban areas with poor water infrastructure',
#   '',
#   ' Analyzing the potential of water-based recreational activities to engage young people in water infrastructure management and conservation',
#   '',
#   ' Developing innovative water infrastructure solutions that prioritize the needs and perspectives of young people',
#   '',
#   ' Assessing the effectiveness of water education programs in schools in promoting water literacy and stewardship among young people',
#   '',
#   " Investigating the impact of climate change on water infrastructure and its implications for young people's livelihoods and well-being",
#   '',
#   ' Examining the role of community-based water management initiatives in empowering young people to take ownership of their water resources',
#   '',
#   ' Developing a framework for inclusive water governance that prioritizes the voices and perspectives of young people',
#   '',
#   ' Investigating the potential of water infrastructure to support sustainable urban planning and development that prioritizes the needs of young people',
#   'I hope these topics provide a good starting point for your research!'],
#  'INTERVIEW 3 21-22 Combined': ['',
#   ' Funding sources for social science research'],
#  'INTERVIEW 4 21-22 Combined': ['',
#   ' Water access and equity',
#   ' Water infrastructure and sustainability',
#   ' Water quality and pollution',
#   ' Water management and governance',
#   ' Water and public health',
#   ' Water and economic development',
#   ' Water and environmental sustainability',
#   ' Water and social justice',
#   ' Water and cultural heritage',
#   ' Water and technological innovation',
#   ''],
#  'INTERVIEW 5 21-22 Combined': ['',
#   ' City budgeting and financial management',
#   ' Grant writing and application processes',
#   ' Self-governance and local autonomy',
#   ' Community development and engagement',
#   ' Economic development and growth strategies',
#   ' Urban planning and infrastructure management',
#   ' Public health and wellness initiatives',
#   ' Education and workforce development programs',
#   ' Cultural diversity and inclusivity in local governance',
#   ' Sustainability and environmental stewardship initiativesI hope these topics are helpful! Let me know if you have any further questions or if you would like me to generate additional topics based on the information provided',
#   ''],
#  'INTERVIEW 6 21-22 Combined': ['',
#   ' Infrastructure and Public Health',
#   ' The Impact of Infrastructure on Health Outcomes',
#   ' The Role of Infrastructure in Shaping Public Health Policies',
#   ' The Intersection of Infrastructure and Public Health'],
#  'INTERVIEW 7 21-22 Combined': ['',
#   ' Continuing education',
#   ' Level [REDACTED] maintenance',
#   ' Buckets',
#   ' Calcium',
#   ' Calcium chloride'],
#  'INTERVIEW 8 21-22 Combined': ['',
#   ' City people and their issues',
#   ' Leadership and turnover in a city',
#   ' Understanding the job and its responsibilities',
#   ' A stereotypical boss and their expectations',
#   ' A foreman who is well-liked',
#   ' An old city administrator and their approach to doing the job better',
#   ' A class for obtaining a CDL and the challenges of running it',
#   ' The impact of COVID on the ability to hold classes in [REDACTED]I hope this helps! Let me know if you have any further queries',
#   ''],
#  'INTERVIEW 9 21-22 Combined': ['',
#   ' Teaching',
#   ' Driving',
#   ' Making money',
#   ' Being a teacher',
#   ' Working in the village',
#   ' Family',
#   ' Choosing to become a driver',
#   ' Water drivers',
#   ' Sewer driversPlease note that these topics are based on the information provided in the conversation and may not be exhaustive or accurate',
#   ''],
#  'Interview 1 April 22': ['', ' Water Filtration Systems'],
#  'Interview 10 April 22': ['',
#   ' Water scarcity and its impact on communities and ecosystems',
#   ' The role of water in sustainable agriculture and food security',
#   ' The impact of climate change on global water resources',
#   ' Water pollution and its effects on human health and the environment',
#   ' The economic and social benefits of water conservation and efficiency measures',
#   ' The role of water in supporting biodiversity and ecosystem services',
#   ' The ethical and moral dimensions of water management and allocation',
#   ' The impact of urbanization and population growth on water resources and infrastructure',
#   ' The potential of new technologies and innovations in water management, such as desalination, water recycling, and wastewater treatment',
#   ' The political and legal frameworks that govern water management and allocation at the local, national, and international levels',
#   ''],
#  'Interview 11 April 22': ['', ' Water scarcity and seasonality'],
#  'Interview 12 April 22': ['',
#   ' The impact of [REDACTED; Introductions] on employee productivity and job satisfaction',
#   '',
#   ' An examination of the effectiveness of different [REDACTED; Introductions] strategies in improving team collaboration and communication',
#   '',
#   ' The role of [REDACTED; Introductions] in shaping organizational culture and values',
#   '',
#   ' A study on the influence of [REDACTED; Introductions] on customer loyalty and retention',
#   '',
#   ' The implications of [REDACTED; Introductions] on organizational decision-making and problem-solving processes',
#   '',
#   ' The impact of [REDACTED; Introductions] on employee turnover and retention rates',
#   '',
#   ' A comparative analysis of the effectiveness of different [REDACTED; Introductions] methods in different industries and organizational settings',
#   '',
#   ' The influence of [REDACTED; Introductions] on employee creativity and innovation',
#   '',
#   ' A study on the relationship between [REDACTED; Introductions] and organizational performance and productivity',
#   '',
#   ' The impact of [REDACTED; Introductions] on employee well-being and mental health',
#   ''],
#  'Interview 13 April 22': ['',
#   ' The impact of climate change on global water resources',
#   ' Water scarcity and drought management strategies',
#   ' The role of water in sustainable agriculture and food security',
#   ' Water pollution and its effects on aquatic ecosystems',
#   ' Water conservation and efficiency measures in urban and industrial settings',
#   ' The social and economic impacts of water scarcity on communities and regions',
#   ' Water-related disasters and emergencies, such as floods and droughts',
#   ' The ethical and moral dimensions of water allocation and distribution',
#   ' The intersection of water and human rights, including access to clean water and sanitation',
#   ' The potential of water to drive innovation and economic growth in emerging markets',
#   ''],
#  'Interview 14 April 22': ['',
#   ' Social media and its impact on mental health',
#   ' The effects of climate change on coastal communities',
#   ' The role of parental involvement in student academic achievement',
#   ' The impact of technology on face-to-face communication',
#   ' The influence of cultural heritage on consumer behavior',
#   ' The effects of sleep deprivation on cognitive function',
#   ' The impact of social inequality on crime rates',
#   ' The role of education in promoting economic growth',
#   ' The effects of social media on political polarization',
#   ' The influence of parental involvement in student drug use',
#   ''],
#  'Interview 15 April 22': ['',
#   ' The impact of COVID- on mental health and well-being',
#   ' The effectiveness of different mask-wearing strategies in preventing the spread of COVID-',
#   ' The economic consequences of COVID- and potential policy responses',
#   ' The role of social distancing in slowing the spread of COVID-',
#   ' The impact of COVID- on marginalized communities and how to address disparities in healthcare access',
#   ' The ethical considerations of vaccine distribution and access during a pandemic',
#   ' The impact of COVID- on education and how to support remote learning',
#   ' The role of technology in facilitating remote work and virtual communication during a pandemic',
#   ' The impact of COVID- on supply chains and how to mitigate disruptions',
#   ' The potential long-term effects of COVID- on public health and society',
#   ''],
#  'Interview 16 April 22': ['',
#   ' Water conservation and efficiency in household water systems',
#   ' Impact of water quality on household water systems and health',
#   ' Household water storage and management systems',
#   ' Water treatment and purification technologies in household settings',
#   ' Energy consumption and sustainability of household water systems',
#   ' Water-energy nexus in household water systems',
#   ' Household water use patterns and behaviors',
#   ' Water-related risks and hazards in household settings',
#   ' Design and implementation of smart water systems in households',
#   ' Integration of water systems with smart home technologiesI hope these topics are helpful! Let me know if you have any further questions',
#   ''],
#  'Interview 17 April 22': ['',
#   ' The impact of storytelling on consumer behavior',
#   ' The role of narrative in shaping cultural identity',
#   ' The use of storytelling in marketing and advertising',
#   ' The effects of media representation on social attitudes',
#   ' The intersection of storytelling and technology',
#   ' The use of narrative in organizational leadership and management',
#   ' The impact of storytelling on employee engagement and motivation',
#   ' The role of storytelling in shaping public policy and advocacy',
#   ' The use of storytelling in education and learning',
#   ' The effects of storytelling on mental health and well-being',
#   ''],
#  'Interview 18 April 22': ['',
#   ' Kitchen water collection',
#   ' Insulation',
#   ' Floor'],
#  'Interview 19 April 22': ['',
#   ' Water quality and taste',
#   ' Gas fuel prices and their impact on consumersI hope this helps! Let me know if you have any further questions',
#   ''],
#  'Interview 2 April 22': ['',
#   ' The impact of water scarcity on agriculture and food security',
#   ' The role of water in sustainable development and the United Nations Sustainable Development Goals (SDGs)',
#   ' The economic and social benefits of water conservation and efficiency measures',
#   ' The impact of climate change on water resources and the resulting challenges for communities and ecosystems',
#   " The role of water in promoting gender equality and women's empowerment",
#   ' The potential of water-based solutions for addressing global challenges such as poverty, inequality, and environmental degradation',
#   ' The impact of urbanization on water management and the resulting challenges for cities and communities',
#   ' The potential of innovative technologies and approaches for improving water management and sustainability',
#   ' The role of water in promoting peace and security, particularly in regions of conflict',
#   ' The potential of water-based tourism and recreation for promoting economic development and cultural exchange',
#   ''],
#  'Interview 20 April 22': ['',
#   ' Water Scarcity and Management in Arid Regions',
#   ' Sustainable Water Collection and Distribution Systems',
#   ' Water Harvesting and Storage Technologies',
#   ' Water Conservation and Efficiency in Industrial Settings',
#   ' The Role of Water Collection in Disaster Response and Recovery',
#   ' Water Collection and Access in Rural and Remote Areas',
#   ' The Impact of Climate Change on Water Collection and Management',
#   ' Water Collection Technologies for Developing Communities',
#   ' The Economics of Water Collection and Distribution',
#   ' Water Collection and Public Health in Developing CountriesI hope these topics are helpful! Let me know if you have any further questions',
#   ''],
#  'Interview 21 April 22': ['',
#   ' Water scarcity and management',
#   ' The impact of climate change on water resources',
#   ' Water quality and pollution',
#   ' Water conservation and efficiency',
#   ' Water infrastructure and sustainability',
#   ' The role of water in sustainable development and poverty reduction',
#   ' Water governance and policy',
#   ' Water and food security',
#   ' Water and energy nexus',
#   ' Water and human healthI hope these topics are helpful! Let me know if you have any further questions',
#   ''],
#  'Interview 22 April 22': ['',
#   ' [REDACTED; Introduction]',
#   ' [REDACTED; Methodology]',
#   ' [REDACTED; Results]',
#   ' [REDACTED; Discussion]',
#   ' [REDACTED; Conclusion]',
#   ' [REDACTED; Implications]',
#   ' [REDACTED; Limitations]',
#   ' [REDACTED; Future Research]Please note that I have not included any numbers before the topics as per your request',
#   ''],
#  'Interview 23 April 22': ['',
#   ' The impact of social media on mental health',
#   ' The effects of technology on face-to-face communication',
#   ' The role of social support in times of stress or uncertainty',
#   ' The influence of societal expectations on individual well-being',
#   ' The relationship between physical activity and mental health',
#   ' The impact of work-related stress on employee well-being',
#   ' The role of mindfulness in managing stress and anxiety',
#   ' The effects of gratitude practices on mental health',
#   ' The influence of social connections on mental health in the digital age',
#   ' The impact of trauma on mental health and well-being',
#   ''],
#  'Interview 24 April 22': ['',
#   ' The impact of social media on mental health',
#   ' The effects of climate change on coastal communities',
#   ' The role of parental involvement in student academic achievement',
#   ' The influence of cultural heritage on consumer behavior',
#   ' The relationship between sleep deprivation and cognitive function',
#   ' The impact of technology on face-to-face communication',
#   ' The effects of poverty on educational outcomes',
#   ' The role of teacher training in student achievement',
#   ' The influence of social norms on health behaviors',
#   ' The impact of political polarization on social cohesionI hope these topics are helpful! Let me know if you need any further assistance',
#   ''],
#  'Interview 25April 22': ['',
#   ' The impact of climate change on water availability and quality',
#   ' Innovative water conservation technologies and strategies',
#   ' Community-based water management and decision-making',
#   ' The role of water in sustainable urban planning and development',
#   ' The social and economic impacts of water scarcity and drought',
#   ' Water infrastructure and resilience in the face of natural disasters and extreme weather events',
#   ' The intersection of water and energy policy'],
#  'Interview 26April 22': ['',
#   ' Water scarcity and management',
#   ' Water quality and pollution',
#   ' Water conservation and efficiency',
#   ' Water infrastructure and development',
#   ' Water governance and policy',
#   ' Water and food security',
#   ' Water and energy nexus',
#   ' Water and climate change',
#   ' Water and human health',
#   ' Water and economic developmentPlease let me know if you would like me to generate more topics or if you have any specific questions related to these topics',
#   ''],
#  'Interview 27 April 22': ['',
#   ' The impact of [REDACTED] on water quality and availability',
#   '',
#   ' The role of water in [REDACTED] and its potential for sustainable development',
#   '',
#   ' The challenges and opportunities of integrating water and [REDACTED] in urban planning and design',
#   '',
#   ' The relationship between water and [REDACTED] in the context of climate change and environmental sustainability',
#   '',
#   ' The potential of [REDACTED] to improve water management and conservation practices',
#   '',
#   ' The cultural and social dimensions of water and [REDACTED] in different regions and communities',
#   '',
#   ' The economic and political factors influencing the use of water and [REDACTED] in various industries and sectors',
#   '',
#   ' The potential of [REDACTED] to enhance water security and resilience in the face of growing global demand and uncertainty',
#   '',
#   ' The role of water and [REDACTED] in promoting sustainable agriculture and food security',
#   '',
#   ' The potential of [REDACTED] to drive innovation and technological advancements in water management and conservation',
#   'I hope these topics provide a useful starting point for your research!'],
#  'Interview 28 April 22': ['',
#   ' The effectiveness of beverage taxes in reducing sugary beverage consumption'],
#  'Interview 29 April 22': ['',
#   ' Shower and toilet dynamics',
#   ' Fluid flow and distribution in shower and toilet environments',
#   ' Impact of shower and toilet design on user experience',
#   ' Water conservation in shower and toilet use',
#   ' The role of showers and toilets in personal hygiene and grooming',
#   ' The influence of cultural and societal factors on shower and toilet preferences',
#   ' The impact of shower and toilet design on user health and well-being',
#   ' The use of technology in shower and toilet design and functionality',
#   ' The role of showers and toilets in sustainable living and environmental impact',
#   ' The future of shower and toilet design and innovation',
#   ''],
#  'Interview 3 April 22': ['',
#   ' Water scarcity and management in drought-prone regions',
#   ' The impact of climate change on global water resources',
#   ' Water pollution and its effects on aquatic ecosystems',
#   ' Water conservation and sustainability in urban areas',
#   ' The role of water in food security and agriculture',
#   ' Water-related conflicts and their resolution mechanisms',
#   ' The impact of water on human health and well-being',
#   ' Water infrastructure and its resilience to natural disasters',
#   ' The role of water in sustainable development and the United Nations Sustainable Development Goals (SDGs)',
#   ' The potential of water-based renewable energy sources, such as hydroelectricity and tidal power',
#   'I hope these topics are helpful! Let me know if you have any further questions',
#   ''],
#  'Interview 30 April 22': ['',
#   ' Levels of testing for [inaudible]',
#   ' Testing methods for [inaudible]',
#   ' Evaluating the effectiveness of testing for [inaudible]',
#   ' The impact of testing on [inaudible]',
#   ' The role of testing in [inaudible]',
#   ' The relationship between testing and [inaudible]',
#   ' Testing for [inaudible] in the context of [inaudible]',
#   ' The challenges and limitations of testing for [inaudible]',
#   ' The future of testing for [inaudible]',
#   ' The ethical considerations of testing for [inaudible]Please note that these are just potential topics based on the provided context information, and there may be other possible topics that could be explored in research papers',
#   ''],
#  'Interview 31 April 22': ['',
#   ' Organizational Change Management',
#   ' Leadership and Innovation',
#   ' Strategic Human Resource Management',
#   ' Employee Engagement and Motivation',
#   ' Organizational Culture and Climate',
#   ' Performance Management and Appraisal',
#   ' Talent Management and Development',
#   ' Diversity and Inclusion in the Workplace',
#   ' Work-Life Balance and Well-being',
#   ' Technology and Innovation in HR ManagementPlease let me know if you need any further assistance',
#   ''],
#  'Interview 32 April 22': ['',
#   ' The Impact of Social Media on Mental Health',
#   ' The Role of Culture in Shaping Consumer Behavior',
#   ' The Effects of Climate Change on Coastal Communities',
#   ' The Impact of Technology on Human Relationships',
#   ' The Influence of Political Ideology on Economic Policy',
#   ' The Effects of Social Isolation on Well-being',
#   ' The Role of Education in Shaping Social Mobility',
#   ' The Impact of Immigration on Labor Markets',
#   ' The Effects of Discrimination on Mental Health',
#   ' The Influence of Social Norms on Environmental Sustainability'],
#  'Interview 33 April 22': ['',
#   ' The impact of water quality on human health',
#   ' The role of water in sustainable agriculture practices',
#   ' The effect of climate change on global water resources',
#   ' The social and economic benefits of water conservation',
#   ' The impact of water scarcity on communities and ecosystems',
#   ' The role of technology in improving water management and efficiency',
#   ' The ethical considerations of water allocation and distribution',
#   ' The relationship between water and food security',
#   ' The impact of water pollution on aquatic ecosystems',
#   ' The potential for water-based renewable energy sources to contribute to a sustainable energy future',
#   ''],
#  'Interview 34 April 22': ['',
#   ' The impact of climate change on water resources',
#   ' Water scarcity and its effects on agriculture and food security',
#   ' The role of water in sustainable development and the United Nations Sustainable Development Goals (SDGs)',
#   ' Water pollution and its effects on human health and the environment',
#   ' Water management and governance in developing countries',
#   ' The economic and social benefits of water conservation and efficiency measures',
#   ' The impact of climate change on water cycles and the hydrological cycle',
#   ' Water and conflict'],
#  'Interview 35 April 22': ['',
#   ' The environmental impact of bottled water production and distribution',
#   '',
#   ' A comparative analysis of the quality of tap water and bottled water in different regions',
#   '',
#   ' The economic and social implications of the bottled water industry on local communities',
#   '',
#   ' An examination of consumer attitudes and behaviors towards bottled water and piped water',
#   '',
#   ' A study on the effectiveness of water filtration systems in improving the quality of tap water',
#   '',
#   ' The role of government regulations in ensuring the safety and quality of both bottled water and piped water',
#   '',
#   ' A survey of the most common contaminants found in bottled water and their potential health effects',
#   '',
#   ' The impact of climate change on the quality and availability of both bottled water and piped water',
#   '',
#   ' A review of the literature on the potential health benefits of drinking water from different sources, including bottled water and piped water',
#   '',
#   ' An analysis of the marketing strategies used by bottled water companies and their impact on consumer perceptions and purchasing decisions',
#   ''],
#  'Interview 36 April 22': ['',
#   ' Water availability and accessibility in [REDACTED]',
#   ' The impact of climate change on water resources in [REDACTED]',
#   ' Water quality and pollution in [REDACTED]',
#   ' Water conservation and management strategies in [REDACTED]',
#   ' The role of water in sustainable development in [REDACTED]',
#   ' The economic and social impacts of water scarcity in [REDACTED]',
#   ' The effectiveness of water policies in [REDACTED]',
#   ' The intersection of water and food security in [REDACTED]',
#   ' The role of technology in improving water management in [REDACTED]',
#   ' The cultural and social dimensions of water in [REDACTED]I hope these topics are helpful! Let me know if you have any further questions',
#   ''],
#  'Interview 37 April 22': ['', ' Water conservation in the home'],
#  'Interview 38 April 22': ['',
#   ' The impact of seasonal changes on water consumption patterns',
#   '',
#   ' Challenges and opportunities in managing water resources in different seasons',
#   '',
#   ' The effect of weather patterns on water quality in various regions',
#   '',
#   ' A comparative analysis of water conservation practices in different seasons',
#   '',
#   ' The role of water in different cultural and religious practices across seasons',
#   '',
#   ' The economic and social impact of seasonal water scarcity on communities',
#   '',
#   ' The potential of seasonal water harvesting and storage technologies',
#   '',
#   ' The influence of seasonal climate change on water management strategies',
#   '',
#   ' The effect of seasonal water pollution on aquatic ecosystems',
#   '',
#   ' The potential of seasonal water-based recreational activities on local economies',
#   'I hope these topics are helpful! Let me know if you have any further questions or if you need additional information',
#   ''],
#  'Interview 39 April 22': ['',
#   ' Chemical Safety and Regulation',
#   ' Environmental Impact of Chemicals',
#   ' Chemical Toxicity and Health Effects',
#   ' Chemical Waste Management and Disposal',
#   ' Sustainable Chemistry and Green Chemistry',
#   ' Chemical Production and Manufacturing Processes',
#   ' Chemical Analysis and Testing Methods',
#   ' Chemical Materials and Nanotechnology',
#   ' Chemical Applications in Medicine and Healthcare',
#   ' Chemicals in the Food Industry and Food SafetyI hope these topics are helpful! Let me know if you have any further questions or requests',
#   ''],
#  'Interview 4 April 22': ['',
#   ' Water scarcity and its impact on communities',
#   ' The role of containers in water distribution and management',
#   ' Innovations in water storage and transportation technologies',
#   ' The economic and environmental costs of water scarcity',
#   ' Community-based water management and governance',
#   ' The impact of climate change on water resources and availability',
#   ' Water security and resilience in the face of global challenges',
#   ' The role of tokenization in water management and trade',
#   ' The intersection of water and energy policy in a changing climate',
#   ' The potential of blockchain technology in water management and distribution',
#   ''],
#  'Interview 40 April 22': ['', ' Water quality and safety'],
#  'Interview 41 April 22': ['',
#   ' The impact of social media on political discourse',
#   ' The role of fake news in shaping public opinion',
#   ' The effects of polarization on democratic institutions',
#   ' The influence of special interest groups on policy-making',
#   ' The rise of populism and its implications for global governance',
#   ' The intersection of race, gender, and politics in the digital age',
#   ' The impact of economic inequality on political participation',
#   ' The role of civil society in promoting democratic values',
#   ' The effects of climate change on political stability',
#   ' The influence of social media on political campaigns and elections',
#   ''],
#  'Interview 5 April 22': ['',
#   ' Community Engagement and Social Cohesion',
#   ' Community Development and Urban Planning',
#   ' Community Health and Wellness',
#   ' Community Identity and Cultural Diversity',
#   ' Community Policing and Crime Prevention',
#   ' Community Resources and Support Networks',
#   ' Community Resilience and Disaster Response',
#   ' Community-Based Education and Skills Development',
#   ' Community-Led Initiatives and Social Entrepreneurship',
#   ' Community-Political Participation and Voter EngagementI hope these topics are helpful! Let me know if you have any further questions or requests',
#   ''],
#  'Interview 6 April 22': ['',
#   ' Water quality and contaminants',
#   ' Water treatment technologies and methods',
#   ' Water infrastructure and management',
#   ' Water scarcity and conservation',
#   ' Water access and equity',
#   ' Water-related diseases and health impacts',
#   ' Water policy and regulation',
#   ' Water-sensitive urban design and planning',
#   ' Water technology and innovation',
#   ' Water governance and international cooperation',
#   ''],
#  'Interview 7 April 22': ['',
#   ' The impact of water scarcity on economic growth and development in [REDACTED]',
#   '',
#   ' An analysis of the effectiveness of different water conservation strategies in [REDACTED]',
#   '',
#   ' The role of technology in addressing water scarcity in [REDACTED]',
#   '',
#   ' The social and cultural factors influencing water use in [REDACTED]',
#   '',
#   ' A comparative study of water management practices in [REDACTED] and [REDACTED]',
#   '',
#   ' The economic and environmental impacts of water privatization in [REDACTED]',
#   '',
#   ' The potential of water harvesting and storage systems in [REDACTED]',
#   '',
#   ' An examination of the political and regulatory frameworks governing water use in [REDACTED]',
#   '',
#   ' The impact of climate change on water resources in [REDACTED]',
#   '',
#   ' A study of the intersection of water and gender in [REDACTED]',
#   'I hope these topics are helpful! Let me know if you have any further questions',
#   ''],
#  'Interview 8 April 22': ['',
#   ' Water scarcity and management in drought-prone regions',
#   ' The impact of climate change on global water resources',
#   ' Water pollution and contamination'],
#  'Interview 9 April 22': ['',
#   ' Pipeline infrastructure and management',
#   ' Deferred revenue accounting and reporting',
#   ' Urban planning and development strategies for water delivery systems',
#   ' Sustainable water management practices and technologies',
#   ' Water pipeline design and engineering',
#   ' Water supply chain management and logistics',
#   ' Financial modeling and forecasting for water infrastructure projects',
#   ' Public-private partnerships in water infrastructure development',
#   ' Water policy and regulation analysis',
#   ' Stakeholder engagement and public participation in water infrastructure planning',
#   '']}
